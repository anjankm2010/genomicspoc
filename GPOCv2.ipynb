# %%
import Bio
print(Bio.__version__)
import os
from Bio.Seq import Seq
from Bio import SeqIO
from Bio.Alphabet import IUPAC
from Bio.Alphabet import generic_nucleotide
from Bio import Align
from Bio.SeqRecord import SeqRecord
from Bio.Seq import MutableSeq
from Bio.Alphabet import generic_dna
import re
from Bio import pairwise2
from Bio.pairwise2 import format_alignment

offsetapplicablepair = 10000000
samenesslookahead = 4
variantnumber = 10
varheadoffset = 0
var_seq_record = 0
ref_gene_name = "BRCA1"
ref_seq_record = SeqIO.read(ref_gene_name+"-REF.fasta", "fasta")

dirpath = 'C:\\Users\\anjan.DESKTOP-PC5VIV8\\GPOC\\testfiles\\'

testfilecount = 0
testfilenames = []
#reporting section
reportlines = []
spcr = "|->| "
#strdiagnone = "Diagnosis: None"
strdiagnone = "---"
# Out:
# 1.77

# %%
reportlines.append("KAIGENIX CLINICAL MANAGEMENT - GENOMICS DEPT.".center(100))
strgeneline = "Genetic Variations Report (for "+ref_gene_name+" gene)\n"
reportlines.append(strgeneline.center(100))

reportlines.append("Details:")
reportlines.append("--------------------------------------------------------------------------------------------------------------------------")

# %%
'''
for root, dirs, files in os.walk(dirpath):
    for filename in files:
            print(filename)
            testfilecount+=1
            testfilenames.append(filename)

print(testfilecount)
for i in range(testfilecount):
    print(str(i) + " -- " + testfilenames[i])
'''
# Out:
# '\nfor root, dirs, files in os.walk(dirpath):\n    for filename in files:\n            print(filename)\n            testfilecount+=1\n            testfilenames.append(filename)\n\nprint(testfilecount)\nfor i in range(testfilecount):\n    print(str(i) + " -- " + testfilenames[i])\n'

# %%
'''
for seq_record in SeqIO.parse("BRCA1-REF.fasta", "fasta"):
    print(seq_record.id)
    print(repr(seq_record.seq))
    print(len(seq_record))
'''
   
#ref_seq_record = SeqIO.read("BRCA1-REF.fasta", "fasta")
# Out:
# '\nfor seq_record in SeqIO.parse("BRCA1-REF.fasta", "fasta"):\n    print(seq_record.id)\n    print(repr(seq_record.seq))\n    print(len(seq_record))\n'

# %%
'''
if variantnumber == 1:
    var_seq_record = SeqIO.read("P001-BRCA1-VAR01.fasta", "fasta")
if variantnumber == 2:
    var_seq_record = SeqIO.read("P001-BRCA1-VAR02.fasta", "fasta")
if variantnumber == 3:
    var_seq_record = SeqIO.read("P001-BRCA1-VAR03.fasta", "fasta")
if variantnumber == 4:
    var_seq_record = SeqIO.read("P001-BRCA1-VAR04.fasta", "fasta")
if variantnumber == 5:
    var_seq_record = SeqIO.read("P001-BRCA1-VAR05.fasta", "fasta")
if variantnumber == 6:
    var_seq_record = SeqIO.read("P001-BRCA1-VAR06.fasta", "fasta")
if variantnumber == 7:
    var_seq_record = SeqIO.read("P001-BRCA1-VAR07.fasta", "fasta")
if variantnumber == 8:
    var_seq_record = SeqIO.read("P001-BRCA1-VAR08.fasta", "fasta")
if variantnumber == 9:
    var_seq_record = SeqIO.read("P001-BRCA1-VAR09.fasta", "fasta")
if variantnumber == 10:
    var_seq_record = SeqIO.read("P001-BRCA1-VAR10.fasta", "fasta") 
'''
# Out:
# '\nif variantnumber == 1:\n    var_seq_record = SeqIO.read("P001-BRCA1-VAR01.fasta", "fasta")\nif variantnumber == 2:\n    var_seq_record = SeqIO.read("P001-BRCA1-VAR02.fasta", "fasta")\nif variantnumber == 3:\n    var_seq_record = SeqIO.read("P001-BRCA1-VAR03.fasta", "fasta")\nif variantnumber == 4:\n    var_seq_record = SeqIO.read("P001-BRCA1-VAR04.fasta", "fasta")\nif variantnumber == 5:\n    var_seq_record = SeqIO.read("P001-BRCA1-VAR05.fasta", "fasta")\nif variantnumber == 6:\n    var_seq_record = SeqIO.read("P001-BRCA1-VAR06.fasta", "fasta")\nif variantnumber == 7:\n    var_seq_record = SeqIO.read("P001-BRCA1-VAR07.fasta", "fasta")\nif variantnumber == 8:\n    var_seq_record = SeqIO.read("P001-BRCA1-VAR08.fasta", "fasta")\nif variantnumber == 9:\n    var_seq_record = SeqIO.read("P001-BRCA1-VAR09.fasta", "fasta")\nif variantnumber == 10:\n    var_seq_record = SeqIO.read("P001-BRCA1-VAR10.fasta", "fasta") \n'

# %%
'''
print(var_seq_record.seq[:100])
print(ref_seq_record.seq[:100])
'''
# Out:
# '\nprint(var_seq_record.seq[:100])\nprint(ref_seq_record.seq[:100])\n'

# %%
def longform(strdiagnosis):
    if strdiagnosis == "BB": return "BENIGN"
    if strdiagnosis == "LB": return "LIKELY BENIGN"
    if strdiagnosis == "PP": return "PATHOLOGICAL"
    if strdiagnosis == "LP": return "LIKELY PATHOLOGICAL"
    if strdiagnosis == "NN": return "NOT KNOWN"
    return "NOT KNOWN"

# %%
#  sample -- c.0010C>T##BB 
def verifyvarient1present(variantrule):
    print("in rule verification 1----------------------" + variantrule)
    global varheadoffset
    global offsetapplicablepair
    global var_seq_record
    global ref_seq_record
    
    start4digitnumber = int(variantrule[2])*1000 + int(variantrule[3])*100 + int(variantrule[4])*10 + int(variantrule[5])*1
    print(start4digitnumber)
    
    if offsetapplicablepair < start4digitnumber:
        varheadoffsetTemp = varheadoffset
    else:
        varheadoffsetTemp = 0
        
    strbeforesubstitution=variantrule[6]
    straftersubstitution=variantrule[8]
    print(strbeforesubstitution)
    print(straftersubstitution)
    print('substitution confirmation 1')
    strdiagnosis = variantrule[11] + variantrule[12]
    print(strdiagnosis)
    print('var head offset 1--' + str(varheadoffsetTemp))
    print('offsetapplicablepair == ' + str(offsetapplicablepair))
    
    print(var_seq_record.seq[start4digitnumber + varheadoffsetTemp])
    print(ref_seq_record.seq[start4digitnumber])
    print('substitution confirmation 2')
    if var_seq_record.seq[start4digitnumber + varheadoffsetTemp] == straftersubstitution:
        if ref_seq_record.seq[start4digitnumber] == strbeforesubstitution:
            reportlines.append("VARIANT "+ spcr + variantrule.ljust(40)+ spcr + "PRESENT  !!!!!!!!!!!!!!  ".ljust(30)+ spcr + "Diagnosis: " + longform(strdiagnosis) )
            print(variantrule + "      PRESENT                               ******************")
        else:
            reportlines.append("VARIANT "+ spcr + variantrule.ljust(40)+ spcr + "Absent".ljust(30)+ spcr + strdiagnone )
    else:
        reportlines.append("VARIANT "+ spcr + variantrule.ljust(40)+ spcr + "Absent".ljust(30)+ spcr + strdiagnone )
        
    # no change to varheadoffset

# %%
#  sample -- c.0005_0008del##LB
def verifyvarient2present(variantrule):
    print("in rule verification 2----------------------" + variantrule)
    global varheadoffset
    global offsetapplicablepair
    global var_seq_record
    global ref_seq_record
    
    start4digitnumber = int(variantrule[2])*1000 + int(variantrule[3])*100 + int(variantrule[4])*10 + int(variantrule[5])*1
    print(start4digitnumber)
    end4digitnumber = int(variantrule[7])*1000 + int(variantrule[8])*100 + int(variantrule[9])*10 + int(variantrule[10])*1
    print(end4digitnumber)
    
    if offsetapplicablepair < start4digitnumber:
        varheadoffsetTemp = varheadoffset
    else:
        varheadoffsetTemp = 0
    
    strdiagnosis = variantrule[16] + variantrule[17]
    print(strdiagnosis)
    print('var head offset 2--' + str(varheadoffsetTemp))
    print('offsetapplicablepair == ' + str(offsetapplicablepair))
    
    difflength = end4digitnumber - start4digitnumber +1
    print(difflength)
    deleted = False
    nextdigitssame = True
    
    strvarsegment = ""
    strrefsegment = ""
    for i in range(difflength):
        print('var ' + var_seq_record.seq[start4digitnumber + varheadoffsetTemp +i])
        print('ref ' + ref_seq_record.seq[start4digitnumber+i])
        strvarsegment = strvarsegment + var_seq_record.seq[start4digitnumber + varheadoffsetTemp +i]
        strrefsegment = strrefsegment + ref_seq_record.seq[start4digitnumber+i]
        if var_seq_record.seq[start4digitnumber +varheadoffsetTemp +i] != ref_seq_record.seq[start4digitnumber+i]:
            deleted = True
    print('strvarsegment ' + strvarsegment)
    print('strrefsegment ' + strrefsegment)
    print('deletion comfirmation above, NOT same is good')
    
    strnextvarsegment = ""
    strnextrefsegment = ""
    for j in range(samenesslookahead):
        print('var next ' + var_seq_record.seq[start4digitnumber + varheadoffsetTemp +j])
        print('ref next ' + ref_seq_record.seq[end4digitnumber+1+j])
        strnextvarsegment = strnextvarsegment + var_seq_record.seq[start4digitnumber + varheadoffsetTemp +j]
        strnextrefsegment = strnextrefsegment + ref_seq_record.seq[end4digitnumber+1+j]
        if var_seq_record.seq[start4digitnumber +varheadoffsetTemp +j] != ref_seq_record.seq[end4digitnumber+1+j]:
            nextdigitssame = False
    print('strnextvarsegment ' + strnextvarsegment)
    print('strnextrefsegment ' + strnextrefsegment)  
    print('same segment confirmation above, same is good')

    
    if deleted == True and nextdigitssame == True:
        reportlines.append("VARIANT "+ spcr + variantrule.ljust(40)+ spcr + "PRESENT  !!!!!!!!!!!!!!  ".ljust(30)+ spcr + "Diagnosis: " + longform(strdiagnosis) )
        print(variantrule + "      PRESENT                              ******************")
        varheadoffset = varheadoffset - difflength
        print('new var head offset --' + str(varheadoffset))
        offsetapplicablepair = min(offsetapplicablepair, start4digitnumber)
        print('new offsetapplicablepair == ' + str(offsetapplicablepair))
    else:
        reportlines.append("VARIANT "+ spcr + variantrule.ljust(40)+ spcr + "Absent".ljust(30)+ spcr + strdiagnone )

# %%
# sample -- c.0009_0012delTCCT##PP
def verifyvarient3present(variantrule):
    print("in rule verification 3----------------------" + variantrule)
    global varheadoffset
    global offsetapplicablepair
    global var_seq_record
    global ref_seq_record
    
    start4digitnumber = int(variantrule[2])*1000 + int(variantrule[3])*100 + int(variantrule[4])*10 + int(variantrule[5])*1
    print(start4digitnumber)
    end4digitnumber = int(variantrule[7])*1000 + int(variantrule[8])*100 + int(variantrule[9])*10 + int(variantrule[10])*1
    print(end4digitnumber)
    
    if offsetapplicablepair < start4digitnumber:
        varheadoffsetTemp = varheadoffset
    else:
        varheadoffsetTemp = 0
        
        #get the string
    strdel=''
    sequencepointer = 14
    while variantrule[sequencepointer] != '#':
        strdel = strdel + variantrule[sequencepointer]
        sequencepointer += 1
    print(strdel)
    
    sequencepointer += 2
    strdiagnosis = variantrule[sequencepointer] + variantrule[sequencepointer+1]
    print(strdiagnosis)
    print('var head offset 3--' + str(varheadoffsetTemp))
    print('offsetapplicablepair == ' + str(offsetapplicablepair))
    
    difflength = end4digitnumber - start4digitnumber +1
    print(difflength)
    deleted = False
    nextdigitssame = True
    rightseqdeleted = True
    
    strvarsegment = ""
    strrefsegment = ""
    for i in range(difflength):
        print('var ' + var_seq_record.seq[start4digitnumber + varheadoffsetTemp +i])
        print('ref ' + ref_seq_record.seq[start4digitnumber+i])
        strvarsegment = strvarsegment + var_seq_record.seq[start4digitnumber + varheadoffsetTemp +i]
        strrefsegment = strrefsegment + ref_seq_record.seq[start4digitnumber+i]
        if var_seq_record.seq[start4digitnumber +varheadoffsetTemp +i] != ref_seq_record.seq[start4digitnumber+i]:
            deleted = True
    print('strvarsegment ' + strvarsegment)
    print('strrefsegment ' + strrefsegment)
    print('deletion comfirmation above, NOT same is good')
    
    strnextvarsegment = ""
    strnextrefsegment = ""
    for j in range(samenesslookahead):
        print('var next ' + var_seq_record.seq[start4digitnumber + varheadoffset +j])
        print('ref next ' + ref_seq_record.seq[end4digitnumber+1+j])
        strnextvarsegment = strnextvarsegment + var_seq_record.seq[start4digitnumber + varheadoffsetTemp +j]
        strnextrefsegment = strnextrefsegment + ref_seq_record.seq[end4digitnumber+1+j]
        if var_seq_record.seq[start4digitnumber +varheadoffsetTemp +j] != ref_seq_record.seq[end4digitnumber+1+j]:
            nextdigitssame = False
    print('strnextvarsegment ' + strnextvarsegment)
    print('strnextrefsegment ' + strnextrefsegment)    
    print('same segment comfirmation above, same is good')
    
    for k in range(difflength):
        print('strdel ' + strdel[k])
        print('ref ' + ref_seq_record.seq[start4digitnumber+k])
        if strdel[k] != ref_seq_record.seq[start4digitnumber+k]:
            rightseqdeleted = False
    print('right seq deleted comfirmation above, same is good')
    
    if deleted == True and rightseqdeleted == True and nextdigitssame == True:
        reportlines.append("VARIANT "+ spcr + variantrule.ljust(40)+ spcr + "PRESENT  !!!!!!!!!!!!!!  ".ljust(30)+ spcr + "Diagnosis: " + longform(strdiagnosis) )
        print(variantrule + "      PRESENT                                ******************")
        varheadoffset = varheadoffset - difflength
        print('new var head offset --' + str(varheadoffset))
        offsetapplicablepair = min(offsetapplicablepair, start4digitnumber)
        print('new offsetapplicablepair == ' + str(offsetapplicablepair))
    else:
        reportlines.append("VARIANT "+ spcr + variantrule.ljust(40)+ spcr + "Absent".ljust(30)+ spcr + strdiagnone )

# %%
# sample -- c.0009_0012dup##LP
def verifyvarient4present(variantrule):
    print("in rule verification 4----------------------" + variantrule)
    global varheadoffset
    global offsetapplicablepair
    global var_seq_record
    global ref_seq_record

        
    start4digitnumber = int(variantrule[2])*1000 + int(variantrule[3])*100 + int(variantrule[4])*10 + int(variantrule[5])*1
    print(start4digitnumber)
    end4digitnumber = int(variantrule[7])*1000 + int(variantrule[8])*100 + int(variantrule[9])*10 + int(variantrule[10])*1
    print(end4digitnumber)
    
        
    if offsetapplicablepair < start4digitnumber:
        varheadoffsetTemp = varheadoffset
    else:
        varheadoffsetTemp = 0
    
    strdiagnosis = variantrule[16] + variantrule[17]
    print(strdiagnosis)
    print('var head offset 4--' + str(varheadoffsetTemp))
    print('offsetapplicablepair == ' + str(offsetapplicablepair))
    #varheadoffset = 412
    
    difflength = end4digitnumber - start4digitnumber +1
    print(difflength)
    duplicated = True
    nextdigitssame = True
   
    
    strvarsegment = ""
    strrefsegment = ""
    for i in range(difflength):
        print('var ' + var_seq_record.seq[end4digitnumber+1 + varheadoffsetTemp +i])
        print('ref ' + ref_seq_record.seq[start4digitnumber+i])
        strvarsegment = strvarsegment + var_seq_record.seq[end4digitnumber +1 + varheadoffsetTemp +i]
        strrefsegment = strrefsegment + ref_seq_record.seq[start4digitnumber+i]
        if var_seq_record.seq[end4digitnumber+1 +varheadoffsetTemp +i] != ref_seq_record.seq[start4digitnumber+i]:
            duplicated = False
    print('strvarsegment ' + strvarsegment)
    print('strrefsegment ' + strrefsegment)
    print('duplication comfirmation above, same is good')
    
    strnextvarsegment = ""
    strnextrefsegment = ""
    for j in range(samenesslookahead):
        print('var next ' + var_seq_record.seq[end4digitnumber+difflength+1 + varheadoffsetTemp +j])
        print('ref next ' + ref_seq_record.seq[end4digitnumber+1+j])
        strnextvarsegment = strnextvarsegment + var_seq_record.seq[end4digitnumber+1+ difflength + varheadoffsetTemp +j]
        strnextrefsegment = strnextrefsegment + ref_seq_record.seq[end4digitnumber+1+j]
        if var_seq_record.seq[end4digitnumber+1+difflength +varheadoffsetTemp +j] != ref_seq_record.seq[end4digitnumber+1+j]:
            nextdigitssame = False
    print('strnextvarsegment ' + strnextvarsegment)
    print('strnextrefsegment ' + strnextrefsegment)  
    print('same segment comfirmation above, same is good')
    
    
    if duplicated == True and nextdigitssame == True:
        reportlines.append("VARIANT "+ spcr + variantrule.ljust(40)+ spcr + "PRESENT  !!!!!!!!!!!!!!  ".ljust(30)+ spcr + "Diagnosis: " + longform(strdiagnosis) )
        print(variantrule + "      PRESENT                                  ******************")
        varheadoffset = varheadoffset + difflength
        print('new var head offset --' + str(varheadoffset))
        offsetapplicablepair = min(offsetapplicablepair, start4digitnumber)
        print('new offsetapplicablepair == ' + str(offsetapplicablepair))
    else:
        reportlines.append("VARIANT "+ spcr + variantrule.ljust(40)+ spcr + "Absent".ljust(30)+ spcr + strdiagnone )

# %%
# sample -- c.0014_0017dupGACG##NN
def verifyvarient5present(variantrule):
    print("in rule verification 5----------------------" + variantrule)
    global varheadoffset
    global offsetapplicablepair
    global var_seq_record
    global ref_seq_record


    
    start4digitnumber = int(variantrule[2])*1000 + int(variantrule[3])*100 + int(variantrule[4])*10 + int(variantrule[5])*1
    print(start4digitnumber)
    end4digitnumber = int(variantrule[7])*1000 + int(variantrule[8])*100 + int(variantrule[9])*10 + int(variantrule[10])*1
    print(end4digitnumber)
    
    if offsetapplicablepair < start4digitnumber:
        varheadoffsetTemp = varheadoffset
    else:
        varheadoffsetTemp = 0
    
    strdup=''
    sequencepointer = 14
    while variantrule[sequencepointer] != '#':
        strdup = strdup + variantrule[sequencepointer]
        sequencepointer += 1
    print(strdup)
    sequencepointer += 2
    strdiagnosis = variantrule[sequencepointer] + variantrule[sequencepointer+1]
    print(strdiagnosis)
    
    print('var head offset 5--' + str(varheadoffsetTemp))
    print('offsetapplicablepair == ' + str(offsetapplicablepair))
    
    difflength = end4digitnumber - start4digitnumber +1
    print(difflength)
    duplicated = True
    nextdigitssame = True
    correctduplicateseq = True
    
    strvarsegment = ""
    strrefsegment = ""
    for i in range(difflength):
        print("var pos = ", str(end4digitnumber+1 + varheadoffsetTemp +i))
        print('var ' + var_seq_record.seq[end4digitnumber+1 + varheadoffsetTemp +i])
        print("ref pos = ", str(start4digitnumber+i))
        print('ref ' + ref_seq_record.seq[start4digitnumber+i])
        strvarsegment = strvarsegment + var_seq_record.seq[end4digitnumber +1 + varheadoffsetTemp +i]
        strrefsegment = strrefsegment + ref_seq_record.seq[start4digitnumber+i]
        if var_seq_record.seq[end4digitnumber+1 +varheadoffsetTemp +i] != ref_seq_record.seq[start4digitnumber+i]:
            duplicated = False
    print('strvarsegment ' + strvarsegment)
    print('strrefsegment ' + strrefsegment)
    print('duplication comfirmation above, same is good')
    
    strnextvarsegment = ""
    strnextrefsegment = ""
    for j in range(samenesslookahead):
        print('var next ' + var_seq_record.seq[end4digitnumber+difflength+1 + varheadoffsetTemp +j])
        print('ref next ' + ref_seq_record.seq[end4digitnumber+1+j])
        strnextvarsegment = strnextvarsegment + var_seq_record.seq[end4digitnumber+1+ difflength + varheadoffsetTemp +j]
        strnextrefsegment = strnextrefsegment + ref_seq_record.seq[end4digitnumber+1+j]
        if var_seq_record.seq[end4digitnumber+1+difflength +varheadoffsetTemp +j] != ref_seq_record.seq[end4digitnumber+1+j]:
            nextdigitssame = False
    print('strnextvarsegment ' + strnextvarsegment)
    print('strnextrefsegment ' + strnextrefsegment) 
    print('same segment comfirmation above, same is good')
    
    for k in range(difflength):
        print('strdup ' + strdup[k])
        print('ref ' + ref_seq_record.seq[start4digitnumber+k])
        if strdup[k] != ref_seq_record.seq[start4digitnumber+k]:
            correctduplicateseq = False
    print('correct duplicate seq comfirmation above, same is good')
            
            
    if duplicated == True and nextdigitssame == True and correctduplicateseq == True:
        reportlines.append("VARIANT "+ spcr + variantrule.ljust(40)+ spcr + "PRESENT  !!!!!!!!!!!!!!  ".ljust(30)+ spcr + "Diagnosis: " + longform(strdiagnosis) )
        print(variantrule + "      PRESENT                                    ******************")
        varheadoffset = varheadoffset + difflength
        print('new var head offset --' + str(varheadoffset))
        offsetapplicablepair = min(offsetapplicablepair, start4digitnumber)
        print('new offsetapplicablepair == ' + str(offsetapplicablepair))
    else:
        reportlines.append("VARIANT "+ spcr + variantrule.ljust(40)+ spcr + "Absent".ljust(30)+ spcr + strdiagnone )
    #varheadoffset = 512

# %%
# sample -- c.0012_0013insATATAT##BB
def verifyvarient6present(variantrule):
    print("in rule verification 6----------------------" + variantrule)
    global varheadoffset
    global offsetapplicablepair
    global var_seq_record
    global ref_seq_record
    
    start4digitnumber = int(variantrule[2])*1000 + int(variantrule[3])*100 + int(variantrule[4])*10 + int(variantrule[5])*1
    print(start4digitnumber)
    end4digitnumber = int(variantrule[7])*1000 + int(variantrule[8])*100 + int(variantrule[9])*10 + int(variantrule[10])*1
    print(end4digitnumber)
    
    if offsetapplicablepair < start4digitnumber:
        varheadoffsetTemp = varheadoffset
    else:
        varheadoffsetTemp = 0
        
    strins=''
    sequencepointer = 14
    while variantrule[sequencepointer] != '#':
        strins = strins + variantrule[sequencepointer]
        sequencepointer += 1
    print(strins)
    lengthstrins = len(strins)
    sequencepointer += 2
    strdiagnosis = variantrule[sequencepointer] + variantrule[sequencepointer+1]
    print(strdiagnosis)
    
    print('var head offset 6--' + str(varheadoffsetTemp))
    print('offsetapplicablepair == ' + str(offsetapplicablepair))
    
    difflength = end4digitnumber - start4digitnumber +1
    print(difflength)
    inserted = True
    nextdigitssame = True
    correctinsertedseq = True
    
    strvarsegment = ""
    strrefsegment = ""
    for i in range(lengthstrins):
        print('var ' + var_seq_record.seq[start4digitnumber+1 + varheadoffsetTemp +i])
        print('ref ' + ref_seq_record.seq[start4digitnumber+1+i])
        strvarsegment = strvarsegment + var_seq_record.seq[start4digitnumber +1 + varheadoffsetTemp +i]
        strrefsegment = strrefsegment + ref_seq_record.seq[start4digitnumber+1+i]
        if var_seq_record.seq[start4digitnumber+1 +varheadoffsetTemp +i] != ref_seq_record.seq[start4digitnumber+1+i]:
            duplicated = False
    print('strvarsegment ' + strvarsegment)
    print('strrefsegment ' + strrefsegment)
    
    print('duplicated? why not inserted? comfirmation above, NOT same is good')
    
    strnextvarsegment = ""
    strnextrefsegment = ""
    for j in range(samenesslookahead):
        print('var next ' + var_seq_record.seq[end4digitnumber+lengthstrins + varheadoffsetTemp +j])
        print('ref next ' + ref_seq_record.seq[end4digitnumber+j])
        strnextvarsegment = strnextvarsegment + var_seq_record.seq[end4digitnumber+ lengthstrins + varheadoffsetTemp +j]
        strnextrefsegment = strnextrefsegment + ref_seq_record.seq[end4digitnumber+j]
        if var_seq_record.seq[end4digitnumber+lengthstrins +varheadoffsetTemp +j] != ref_seq_record.seq[end4digitnumber+j]:
            nextdigitssame = False
    print('strnextvarsegment ' + strnextvarsegment)
    print('strnextrefsegment ' + strnextrefsegment)    
    print('same segment comfirmation above, same is good')
    
    for k in range(lengthstrins):
        print('strins ' + strins[k])
        print('var ' + var_seq_record.seq[start4digitnumber+1+k])
        if strins[k] != var_seq_record.seq[start4digitnumber+1+k]:
            correctinsertedseq = False
    
    print('correct inserted seq comfirmation above, same is good')
            
            
    if inserted == True and nextdigitssame == True and correctinsertedseq == True:
        reportlines.append("VARIANT "+ spcr + variantrule.ljust(40)+ spcr + "PRESENT  !!!!!!!!!!!!!!  ".ljust(30)+ spcr + "Diagnosis: " + longform(strdiagnosis) )
        print(variantrule + "      PRESENT                                    ******************")
        varheadoffset = varheadoffset + lengthstrins
        print('new var head offset --' + str(varheadoffset))
        offsetapplicablepair = min(offsetapplicablepair, start4digitnumber)
        print('new offsetapplicablepair == ' + str(offsetapplicablepair))
    else:
        reportlines.append("VARIANT "+ spcr + variantrule.ljust(40)+ spcr + "Absent".ljust(30)+ spcr + strdiagnone )
    #varheadoffset = 512

# %%
# sample -- c.0009_0010delinsGGAA##LP
def verifyvarient7present(variantrule):
    print("in rule verification 7----------------------" + variantrule)
    global varheadoffset
    global offsetapplicablepair
    global var_seq_record
    global ref_seq_record
    
    start4digitnumber = int(variantrule[2])*1000 + int(variantrule[3])*100 + int(variantrule[4])*10 + int(variantrule[5])*1
    print(start4digitnumber)
    end4digitnumber = int(variantrule[7])*1000 + int(variantrule[8])*100 + int(variantrule[9])*10 + int(variantrule[10])*1
    print(end4digitnumber)
    
    if offsetapplicablepair < start4digitnumber:
        varheadoffsetTemp = varheadoffset
    else:
        varheadoffsetTemp = 0
        
    strdelins=''
    sequencepointer = 17
    while variantrule[sequencepointer] != '#':
        strdelins = strdelins + variantrule[sequencepointer]
        sequencepointer += 1
    print(strdelins)
    lengthstrdelins = len(strdelins)
    
    sequencepointer += 2
    strdiagnosis = variantrule[sequencepointer] + variantrule[sequencepointer+1]
    print(strdiagnosis)
    
    print('var head offset 7--' + str(varheadoffsetTemp))
    print('offsetapplicablepair == ' + str(offsetapplicablepair))
    #varheadoffset = 712
    
    difflength = end4digitnumber - start4digitnumber +1
    print(difflength)
    deleted = False
    inserted = True
    nextdigitssame = True
    correctinsertedseq = True
    
    strvarsegment = ""
    strrefsegment = ""
    for i in range(difflength):
        print('var ' + var_seq_record.seq[start4digitnumber + varheadoffsetTemp +i])
        print('ref ' + ref_seq_record.seq[start4digitnumber+i])
        strvarsegment = strvarsegment + var_seq_record.seq[start4digitnumber + varheadoffsetTemp +i]
        strrefsegment = strrefsegment + ref_seq_record.seq[start4digitnumber+i]
        if var_seq_record.seq[start4digitnumber +varheadoffsetTemp +i] != ref_seq_record.seq[start4digitnumber+i]:
            deleted = True
    print('strvarsegment ' + strvarsegment)
    print('strrefsegment ' + strrefsegment)
    
    print('deleted comfirmation above, not same is true')
    
    strnextvarsegment = ""
    strnextrefsegment = ""
    for j in range(samenesslookahead):
        print('var next ' + var_seq_record.seq[start4digitnumber+lengthstrdelins + varheadoffsetTemp +j])
        print('ref next ' + ref_seq_record.seq[end4digitnumber+1+j])
        strnextvarsegment = strnextvarsegment + var_seq_record.seq[start4digitnumber+ lengthstrdelins + varheadoffsetTemp +j]
        strnextrefsegment = strnextrefsegment + ref_seq_record.seq[end4digitnumber+1+j]
        if var_seq_record.seq[start4digitnumber+lengthstrdelins +varheadoffsetTemp +j] != ref_seq_record.seq[end4digitnumber+1+j]:
            nextdigitssame = False
    print('strnextvarsegment ' + strnextvarsegment)
    print('strnextrefsegment ' + strnextrefsegment) 
    
    print('same segment comfirmation above, same is good')
    
    for k in range(lengthstrdelins):
        print('strdelins ' + strdelins[k])
        print('var ' + var_seq_record.seq[start4digitnumber+k])
        if strdelins[k] != var_seq_record.seq[start4digitnumber+k]:
            correctinsertedseq = False
    
    print('correct inserted seq comfirmation above, same is good')
    
    if deleted == True and nextdigitssame == True and correctinsertedseq == True:
        reportlines.append("VARIANT "+ spcr + variantrule.ljust(40)+ spcr + "PRESENT  !!!!!!!!!!!!!!  ".ljust(30)+ spcr + "Diagnosis: " + longform(strdiagnosis) )
        print(variantrule + "      PRESENT                                               ******************")
        varheadoffset = varheadoffset - difflength + lengthstrdelins
        print('new var head offset --' + str(varheadoffset))
        offsetapplicablepair = min(offsetapplicablepair, start4digitnumber)
        print('new offsetapplicablepair == ' + str(offsetapplicablepair))
        
    else:
        reportlines.append("VARIANT "+ spcr + variantrule.ljust(40)+ spcr + "Absent".ljust(30)+ spcr + strdiagnone )
    #varheadoffset = 512

# %%
# sample -- c.0009_0010delTCinsGGAA##LP
def verifyvarient8present(variantrule):
    print("in rule verification 8 ----------------------" + variantrule)
    global varheadoffset
    global offsetapplicablepair
    global var_seq_record
    global ref_seq_record
    
    start4digitnumber = int(variantrule[2])*1000 + int(variantrule[3])*100 + int(variantrule[4])*10 + int(variantrule[5])*1
    print(start4digitnumber)
    end4digitnumber = int(variantrule[7])*1000 + int(variantrule[8])*100 + int(variantrule[9])*10 + int(variantrule[10])*1
    print(end4digitnumber)
    
    if offsetapplicablepair < start4digitnumber:
        varheadoffsetTemp = varheadoffset
    else:
        varheadoffsetTemp = 0
    
    strdel=''
    sequencepointer = 14
    char = variantrule[sequencepointer]
    print(char)
    while ((char != 'I') and (char != 'i')):
        strdel = strdel + char
        sequencepointer += 1
        char = variantrule[sequencepointer]
        print(char)
    print(strdel)
    lengthstrdel = len(strdel)
    
    strins=''
    sequencepointer += 3
    while variantrule[sequencepointer] != '#':
        strins = strins + variantrule[sequencepointer]
        sequencepointer += 1
    print(strins)
    lengthstrins = len(strins)
    
    sequencepointer += 2
    strdiagnosis = variantrule[sequencepointer] + variantrule[sequencepointer+1]
    print(strdiagnosis)
    
    print('var head offset 8--' + str(varheadoffsetTemp))
    print('offsetapplicablepair == ' + str(offsetapplicablepair))
    #varheadoffset = 712
    
    difflength = end4digitnumber - start4digitnumber +1
    print(difflength)
    deleted = False
    inserted = True
    nextdigitssame = True
    correctdeletedseq = True
    correctinsertedseq = True
    
    strvarsegment = ""
    strrefsegment = ""
    for i in range(difflength):
        print('var ' + var_seq_record.seq[start4digitnumber + varheadoffsetTemp +i])
        print('ref ' + ref_seq_record.seq[start4digitnumber+i])
        strvarsegment = strvarsegment + var_seq_record.seq[start4digitnumber + varheadoffsetTemp +i]
        strrefsegment = strrefsegment + ref_seq_record.seq[start4digitnumber+i]
        if var_seq_record.seq[start4digitnumber +varheadoffsetTemp +i] != ref_seq_record.seq[start4digitnumber+i]:
            deleted = True
    print('strvarsegment ' + strvarsegment)
    print('strrefsegment ' + strrefsegment)
    
    print('deleted comfirmation above. not same is good')
    
    strnextvarsegment = ""
    strnextrefsegment = ""
    for j in range(samenesslookahead):
        print('var next ' + var_seq_record.seq[start4digitnumber+lengthstrins + varheadoffsetTemp +j])
        print('ref next ' + ref_seq_record.seq[end4digitnumber+1+j])
        strnextvarsegment = strnextvarsegment + var_seq_record.seq[start4digitnumber+ lengthstrins + varheadoffsetTemp +j]
        strnextrefsegment = strnextrefsegment + ref_seq_record.seq[end4digitnumber+1+j]
        if var_seq_record.seq[start4digitnumber+lengthstrins +varheadoffsetTemp +j] != ref_seq_record.seq[end4digitnumber+1+j]:
            nextdigitssame = False
    print('strnextvarsegment ' + strnextvarsegment)
    print('strnextrefsegment ' + strnextrefsegment) 
    
    print('same segment comfirmation above, same is good')
    
    for k in range(lengthstrdel):
        print('strdel ' + strdel[k])
        print('ref ' + ref_seq_record.seq[start4digitnumber+k])
        if strdel[k] != ref_seq_record.seq[start4digitnumber+k]:
            correctdeletedseq = False
            
    print('correct deleted seq comfirmation above, same is good')
    
    for l in range(lengthstrins):
        print('strins ' + strins[l])
        print('var ' + var_seq_record.seq[start4digitnumber+l])
        if strins[l] != var_seq_record.seq[start4digitnumber+l]:
            correctinsertedseq = False
    print('correct inserted seq comfirmation above, same is good')
    
    if deleted == True and nextdigitssame == True and correctinsertedseq == True and correctdeletedseq == True:
        reportlines.append("VARIANT "+ spcr + variantrule.ljust(40)+ spcr + "PRESENT  !!!!!!!!!!!!!!  ".ljust(30)+ spcr + "Diagnosis: " + longform(strdiagnosis) )
        print(variantrule + "      PRESENT                                       ******************")
        varheadoffset = varheadoffset + difflength
        print('new var head offset --' + str(varheadoffset))
        offsetapplicablepair = min(offsetapplicablepair, start4digitnumber)
        print('new offsetapplicablepair == ' + str(offsetapplicablepair))
    else:
        reportlines.append("VARIANT "+ spcr + variantrule.ljust(40)+ spcr+ "Absent".ljust(30)+ spcr + strdiagnone )
    #varheadoffset = 512

# %%
# sample -- c.0021_0039inv##PP
def verifyvarient9present(variantrule):
    #c.0021_0039inv##PP
    print("in rule verification 9 ----------------------" + variantrule)
    global varheadoffset
    global offsetapplicablepair
    global var_seq_record
    global ref_seq_record
    #feature_seq = example_parent[example_feature.location.start:example_feature.location.end].reverse_complement()
    
    start4digitnumber = int(variantrule[2])*1000 + int(variantrule[3])*100 + int(variantrule[4])*10 + int(variantrule[5])*1
    print(start4digitnumber)
    end4digitnumber = int(variantrule[7])*1000 + int(variantrule[8])*100 + int(variantrule[9])*10 + int(variantrule[10])*1
    print(end4digitnumber)
    
    if offsetapplicablepair < start4digitnumber:
        varheadoffsetTemp = varheadoffset
    else:
        varheadoffsetTemp = 0
    

    sequencepointer = 16
    strdiagnosis = variantrule[sequencepointer] + variantrule[sequencepointer+1]
    print(strdiagnosis)
    
    print('var head offset 9--' + str(varheadoffsetTemp))
    print('offsetapplicablepair == ' + str(offsetapplicablepair))
    
    
    difflength = end4digitnumber - start4digitnumber +1
    print(difflength)
    
    isinverted = True
    
    nextdigitssame = True

    invertedseq = var_seq_record.seq[start4digitnumber+varheadoffsetTemp:end4digitnumber+varheadoffsetTemp+1]
    
    correspondingrefseq = ref_seq_record.seq[start4digitnumber:end4digitnumber+1]
    
    
    print(invertedseq)
    originalseqfromvarseq = invertedseq.reverse_complement()
    print(originalseqfromvarseq)
    
    print(correspondingrefseq)
    
    
    strvarsegment = ""
    strrefsegment = ""
    for i in range(difflength):
        print('var ' + originalseqfromvarseq[i])
        print('ref ' + correspondingrefseq[i])
        if originalseqfromvarseq[i] != correspondingrefseq[i]:
            isinverted = False
    print('strvarsegment which is inverted ' + invertedseq)
    print('strvarsegment which is inverted back ' + originalseqfromvarseq)
    print('strrefsegment ' + correspondingrefseq)
    
    print('inversion reverse complement comfirmation above, same [2 and 3] is good')
    
    strnextvarsegment = ""
    strnextrefsegment = ""
    for j in range(samenesslookahead):
        print('var next ' + var_seq_record.seq[start4digitnumber+difflength + varheadoffsetTemp +j])
        print('ref next ' + ref_seq_record.seq[end4digitnumber+1+j])
        strnextvarsegment = strnextvarsegment + var_seq_record.seq[start4digitnumber+ difflength + varheadoffsetTemp +j]
        strnextrefsegment = strnextrefsegment + ref_seq_record.seq[end4digitnumber+1+j]
        if var_seq_record.seq[start4digitnumber+difflength +varheadoffsetTemp +j] != ref_seq_record.seq[end4digitnumber+1+j]:
            nextdigitssame = False
    print('strnextvarsegment ' + strnextvarsegment)
    print('strnextrefsegment ' + strnextrefsegment) 
    print('same segment comfirmation above, same is good')
             
    if isinverted == True and nextdigitssame == True :
        reportlines.append("VARIANT "+ spcr + variantrule.ljust(40)+ spcr + "PRESENT  !!!!!!!!!!!!!!  ".ljust(30)+ spcr + "Diagnosis: " + longform(strdiagnosis) )
        print(variantrule + "      PRESENT                                      ******************")
        #varheadoffset = varheadoffset + difflength ---commented, no change in length of the sequence due to the variation
        #varheadoffsetTemp = min(varheadoffsetTemp, start4digitnumber)
    else:
        reportlines.append("VARIANT "+ spcr + variantrule.ljust(40)+ spcr + "Absent".ljust(30)+ spcr + strdiagnone )

# %%
# sample -- c.0021_0039con0061_0079##LP
def verifyvarient10present(variantrule):
    print("in rule verification 10 ----------------------" + variantrule)
    global varheadoffset
    global offsetapplicablepair
    global var_seq_record
    global ref_seq_record
   
    #c.0021_0039con0061_0079##LP
    
    start4digitnumber = int(variantrule[2])*1000 + int(variantrule[3])*100 + int(variantrule[4])*10 + int(variantrule[5])*1
    print(start4digitnumber)
    end4digitnumber = int(variantrule[7])*1000 + int(variantrule[8])*100 + int(variantrule[9])*10 + int(variantrule[10])*1
    print(end4digitnumber)
    
    if offsetapplicablepair < start4digitnumber:
        varheadoffsetTemp = varheadoffset
    else:
        varheadoffsetTemp = 0
    
    start4digitnumbercon = int(variantrule[14])*1000 + int(variantrule[14])*100 + int(variantrule[16])*10 + int(variantrule[17])*1
    print(start4digitnumbercon)
    end4digitnumbercon = int(variantrule[19])*1000 + int(variantrule[20])*100 + int(variantrule[21])*10 + int(variantrule[22])*1
    print(end4digitnumbercon)

    sequencepointer = 25
    strdiagnosis = variantrule[sequencepointer] + variantrule[sequencepointer+1]
    print(strdiagnosis)
    
    print('var head offset 10--' + str(varheadoffsetTemp))
    print('offsetapplicablepair == ' + str(offsetapplicablepair))
    
    print("FFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFF")
    
    islengthsame = False
    isconverted = True
    nextdigitssame = True
    
    difflength = end4digitnumber - start4digitnumber +1
    print(difflength)
    difflengthcon = end4digitnumbercon - start4digitnumbercon +1
    print(difflengthcon)
    if difflength == difflengthcon:
        islengthsame = True
    
    strvarsegment = ""
    strrefsegment = ""
    for i in range(difflength):
        print('var ' + var_seq_record.seq[start4digitnumber + varheadoffsetTemp +i])
        print('refcon ' + ref_seq_record.seq[start4digitnumbercon+i])
        strvarsegment = strvarsegment + var_seq_record.seq[start4digitnumber + varheadoffsetTemp +i]
        strrefsegment = strrefsegment + ref_seq_record.seq[start4digitnumbercon+i]
        if var_seq_record.seq[start4digitnumber +varheadoffsetTemp +i] != ref_seq_record.seq[start4digitnumbercon+i]:
            isconverted = False
    print('strvarsegment ' + strvarsegment)
    print('strrefsegment ' + strrefsegment)
    print('converted comfirmation above, i.e same [var, ref-con] is good')
    
    
    strnextvarsegment = ""
    strnextrefsegment = ""
    for j in range(samenesslookahead):
        print('var next ' + var_seq_record.seq[start4digitnumber+difflength + varheadoffsetTemp +j])
        print('ref next ' + ref_seq_record.seq[end4digitnumber+1+j])
        strnextvarsegment = strnextvarsegment + var_seq_record.seq[start4digitnumber+ difflength + varheadoffsetTemp +j]
        strnextrefsegment = strnextrefsegment + ref_seq_record.seq[end4digitnumber+1+j]
        if var_seq_record.seq[start4digitnumber+difflength +varheadoffsetTemp +j] != ref_seq_record.seq[end4digitnumber+1+j]:
            nextdigitssame = False
    print('strnextvarsegment ' + strnextvarsegment)
    print('strnextrefsegment ' + strnextrefsegment) 
    print('same segment comfirmation above, same is good')
             
    if isconverted == True and nextdigitssame == True and islengthsame == True:
        reportlines.append("VARIANT "+ spcr + variantrule.ljust(40)+ spcr + "PRESENT   !!!!!!!!!!!!!! ".ljust(30)+ spcr + "Diagnosis: " + longform(strdiagnosis) )
        print(variantrule + "      PRESENT                                         ******************")
        #varheadoffset = varheadoffset + difflength ---commented, no change in length of the sequence due to the variation
        #varheadoffsetTemp = min(varheadoffsetTemp, start4digitnumber)
    else:
        reportlines.append("VARIANT "+ spcr + variantrule.ljust(40)+ spcr + "Absent".ljust(30)+ spcr + strdiagnone )

# %%
import re

def checkvariantexists(variantnumber, variantrule ):
    #print(variantnumber)
    #print(variantrule)
    match = 0
    matchObj1 = re.match( r'c\.\d\d\d\d[a-zA-Z]>[a-zA-Z]##', variantrule)
    if matchObj1:
        print('\n\n Variant#' + str(variantnumber)+' Variant:'+variantrule + ' --- matched 1')
        match = 1
        isvarientpresent = verifyvarient1present(variantrule)
        
    matchObj2 = re.match( r'c\.\d\d\d\d_\d\d\d\d[Dd][Ee][Ll]##', variantrule)
    if matchObj2:
        print('\n\n Variant#' + str(variantnumber)+' Variant:'+variantrule + ' --- matched 2')
        match = 1
        isvarientpresent = verifyvarient2present(variantrule)
        
    matchObj3 = re.match( r'c\.\d\d\d\d_\d\d\d\d[Dd][Ee][Ll][atgcATGC]+##', variantrule)
    if matchObj3:
        print('\n\n Variant#' + str(variantnumber)+' Variant:'+variantrule + ' --- matched 3')
        match = 1
        isvarientpresent = verifyvarient3present(variantrule)
        
    matchObj4 = re.match( r'c\.\d\d\d\d_\d\d\d\d[Dd][Uu][Pp]##', variantrule)
    if matchObj4:
        print('\n\n Variant#' + str(variantnumber)+' Variant:'+variantrule + ' --- matched 4')
        match = 1
        isvarientpresent = verifyvarient4present(variantrule)
        
    matchObj5 = re.match( r'c\.\d\d\d\d_\d\d\d\d[Dd][Uu][Pp][atgcATGC]+##', variantrule)
    if matchObj5:
        print('\n\n Variant#' + str(variantnumber)+' Variant:'+variantrule + ' --- matched 5')
        match = 1
        isvarientpresent = verifyvarient5present(variantrule)
        
    matchObj6 = re.match( r'c\.\d\d\d\d_\d\d\d\d[Ii][Nn][Ss][atgcATGC]+##', variantrule)
    if matchObj6:
        print('\n\n Variant#' + str(variantnumber)+' Variant:'+variantrule + ' --- matched 6')
        match = 1
        isvarientpresent = verifyvarient6present(variantrule)
        
    matchObj7 = re.match( r'c\.\d\d\d\d_\d\d\d\d[Dd][Ee][Ll][Ii][Nn][Ss][atgcATGC]+##', variantrule)
    if matchObj7:
        print('\n\n Variant#' + str(variantnumber)+' Variant:'+variantrule + ' --- matched 7')
        match = 1
        isvarientpresent = verifyvarient7present(variantrule)
        
    matchObj8 = re.match( r'c\.\d\d\d\d_\d\d\d\d[Dd][Ee][Ll][atgcATGC]+[Ii][Nn][Ss][atgcATGC]+##', variantrule)
    if matchObj8:
        print('\n\n Variant#' + str(variantnumber)+' Variant:'+variantrule + ' --- matched 8')
        match = 1
        isvarientpresent = verifyvarient8present(variantrule)
    
    #0021_0039inv##PP
    matchObj9 = re.match( r'c\.\d\d\d\d_\d\d\d\d[Ii][Nn][Vv]##', variantrule)
    if matchObj9:
        print('\n\n Variant#' + str(variantnumber)+' Variant:'+variantrule + ' --- matched 9')
        match = 1
        isvarientpresent = verifyvarient9present(variantrule)
        
    matchObj10 = re.match( r'c\.\d\d\d\d_\d\d\d\d[Cc][Oo][Nn]\d\d\d\d_\d\d\d\d##', variantrule)
    if matchObj10:
        print('\n\n Variant#' + str(variantnumber)+' Variant:'+variantrule + ' --- matched 10')
        match = 1
        isvarientpresent = verifyvarient10present(variantrule)
        
    if match == 0:
        print('\n\n Variant#' + str(variantnumber)+' Variant:'+variantrule + ' --- NO MATCHING RULE FOUND!!!!!')

# %%
'''
print(var_seq_record.seq[:100])
print(ref_seq_record.seq[:100])
'''
# Out:
# '\nprint(var_seq_record.seq[:100])\nprint(ref_seq_record.seq[:100])\n'

# %%
import re
netdeletes=0
netinserts=0
netduplicates=0

global var_seq_record
global ref_seq_record

file1 = open('BRCA1-VARIANTS.txt', 'r') 
Variants = file1.readlines() 

for root, dirs, files in os.walk(dirpath):
    for filename in files:
            print(filename)
            testfilecount+=1
            testfilenames.append(filename)

print(testfilecount)
for i in range(testfilecount):
    print(str(i) + " -- " + testfilenames[i])
    var_seq_record = SeqIO.read(dirpath+testfilenames[i], "fasta")
    reportlines.append("--------------------------------------------------------------------------------------------------------------------------")
    reportlines.append("For file:   " + testfilenames[i])
    reportlines.append(var_seq_record.seq[:20]+'|'+var_seq_record.seq[20:40]+'|'+var_seq_record.seq[40:60]+'|'+var_seq_record.seq[60:80]+'|'+var_seq_record.seq[80:100])
    reportlines.append(ref_seq_record.seq[:20]+'|'+ref_seq_record.seq[20:40]+'|'+ref_seq_record.seq[40:60]+'|'+ref_seq_record.seq[60:80]+'|'+ref_seq_record.seq[80:100])
    reportlines.append("--------------------------------------------------------------------------------------------------------------------------")
    varheadoffset = 0
    count = 0
    # Strips the newline character 
    for variant in Variants: 
        #print("Line {}: {}".format(count+1, variant.strip()))
        checkvariantexists(count+1, variant.strip() )
        count+=1
        
reportlines.append("--------------------------------------------------------------------------------------------------------------------------")
reportlines.append("===============================================END OF GENOMICS REPORT=====================================================")
# Out:
# P001-BRCA1-VAR01.fasta
# P001-BRCA1-VAR02.fasta
# P001-BRCA1-VAR03.fasta
# P001-BRCA1-VAR04.fasta
# P001-BRCA1-VAR05.fasta
# P001-BRCA1-VAR06.fasta
# P001-BRCA1-VAR07.fasta
# P001-BRCA1-VAR08.fasta
# P001-BRCA1-VAR09.fasta
# P001-BRCA1-VAR10.fasta
# P002-BRCA1-VAR01.fasta
# P002-BRCA1-VAR02.fasta
# P002-BRCA1-VAR03.fasta
# P002-BRCA1-VAR04.fasta
# P002-BRCA1-VAR05.fasta
# P002-BRCA1-VAR06.fasta
# P002-BRCA1-VAR07.fasta
# P002-BRCA1-VAR08.fasta
# P002-BRCA1-VAR09.fasta
# P002-BRCA1-VAR10.fasta
# P003-BRCA1-VAR01.fasta
# P003-BRCA1-VAR02.fasta
# P003-BRCA1-VAR03.fasta
# P003-BRCA1-VAR04.fasta
# P003-BRCA1-VAR05.fasta
# P003-BRCA1-VAR06.fasta
# P003-BRCA1-VAR07.fasta
# P003-BRCA1-VAR08.fasta
# P003-BRCA1-VAR09.fasta
# P003-BRCA1-VAR10.fasta
# 30
# 0 -- P001-BRCA1-VAR01.fasta
#
#
#  Variant#1 Variant:c.0010C>T##BB --- matched 1
# in rule verification 1----------------------c.0010C>T##BB
# 10
# C
# T
# substitution confirmation 1
# BB
# var head offset 1--0
# offsetapplicablepair == 10000000
# T
# C
# substitution confirmation 2
# c.0010C>T##BB      PRESENT                               ******************
#
#
#  Variant#2 Variant:c.0005_0008del##LB --- matched 2
# in rule verification 2----------------------c.0005_0008del##LB
# 5
# 8
# LB
# var head offset 2--0
# offsetapplicablepair == 10000000
# 4
# var G
# ref G
# var A
# ref A
# var C
# ref C
# var T
# ref T
# strvarsegment GACT
# strrefsegment GACT
# deletion comfirmation above, NOT same is good
# var next G
# ref next T
# var next A
# ref next C
# var next C
# ref next C
# var next T
# ref next T
# strnextvarsegment GACT
# strnextrefsegment TCCT
# same segment confirmation above, same is good
#
#
#  Variant#3 Variant:c.0009_0012delTCCT##PP --- matched 3
# in rule verification 3----------------------c.0009_0012delTCCT##PP
# 9
# 12
# TCCT
# PP
# var head offset 3--0
# offsetapplicablepair == 10000000
# 4
# var T
# ref T
# var T
# ref C
# var C
# ref C
# var T
# ref T
# strvarsegment TTCT
# strrefsegment TCCT
# deletion comfirmation above, NOT same is good
# var next T
# ref next G
# var next T
# ref next G
# var next C
# ref next A
# var next T
# ref next C
# strnextvarsegment TTCT
# strnextrefsegment GGAC
# same segment comfirmation above, same is good
# strdel T
# ref T
# strdel C
# ref C
# strdel C
# ref C
# strdel T
# ref T
# right seq deleted comfirmation above, same is good
#
#
#  Variant#4 Variant:c.0009_0012dup##LP --- matched 4
# in rule verification 4----------------------c.0009_0012dup##LP
# 9
# 12
# LP
# var head offset 4--0
# offsetapplicablepair == 10000000
# 4
# var G
# ref T
# var G
# ref C
# var A
# ref C
# var C
# ref T
# strvarsegment GGAC
# strrefsegment TCCT
# duplication comfirmation above, same is good
# var next G
# ref next G
# var next G
# ref next G
# var next G
# ref next A
# var next G
# ref next C
# strnextvarsegment GGGG
# strnextrefsegment GGAC
# same segment comfirmation above, same is good
#
#
#  Variant#5 Variant:c.0014_0017dupGACG##NN --- matched 5
# in rule verification 5----------------------c.0014_0017dupGACG##NN
# 14
# 17
# GACG
# NN
# var head offset 5--0
# offsetapplicablepair == 10000000
# 4
# var pos =  18
# var G
# ref pos =  14
# ref G
# var pos =  19
# var G
# ref pos =  15
# ref A
# var pos =  20
# var G
# ref pos =  16
# ref C
# var pos =  21
# var G
# ref pos =  17
# ref G
# strvarsegment GGGG
# strrefsegment GACG
# duplication comfirmation above, same is good
# var next A
# ref next G
# var next C
# ref next G
# var next A
# ref next G
# var next G
# ref next G
# strnextvarsegment ACAG
# strnextrefsegment GGGG
# same segment comfirmation above, same is good
# strdup G
# ref G
# strdup A
# ref A
# strdup C
# ref C
# strdup G
# ref G
# correct duplicate seq comfirmation above, same is good
#
#
#  Variant#6 Variant:c.0012_0013insATATAT##BB --- matched 6
# in rule verification 6----------------------c.0012_0013insATATAT##BB
# 12
# 13
# ATATAT
# BB
# var head offset 6--0
# offsetapplicablepair == 10000000
# 2
# var G
# ref G
# var G
# ref G
# var A
# ref A
# var C
# ref C
# var G
# ref G
# var G
# ref G
# strvarsegment GGACGG
# strrefsegment GGACGG
# duplicated? why not inserted? comfirmation above, NOT same is good
# var next G
# ref next G
# var next G
# ref next G
# var next G
# ref next A
# var next A
# ref next C
# strnextvarsegment GGGA
# strnextrefsegment GGAC
# same segment comfirmation above, same is good
# strins A
# var G
# strins T
# var G
# strins A
# var A
# strins T
# var C
# strins A
# var G
# strins T
# var G
# correct inserted seq comfirmation above, same is good
#
#
#  Variant#7 Variant:c.0009_0010delinsGGAA##LP --- matched 7
# in rule verification 7----------------------c.0009_0010delinsGGAA##LP
# 9
# 10
# GGAA
# LP
# var head offset 7--0
# offsetapplicablepair == 10000000
# 2
# var T
# ref T
# var T
# ref C
# strvarsegment TT
# strrefsegment TC
# deleted comfirmation above, not same is true
# var next G
# ref next C
# var next G
# ref next T
# var next A
# ref next G
# var next C
# ref next G
# strnextvarsegment GGAC
# strnextrefsegment CTGG
# same segment comfirmation above, same is good
# strdelins G
# var T
# strdelins G
# var T
# strdelins A
# var C
# strdelins A
# var T
# correct inserted seq comfirmation above, same is good
#
#
#  Variant#8 Variant:c.0009_0010delTCinsTAGC##LP --- matched 8
# in rule verification 8 ----------------------c.0009_0010delTCinsTAGC##LP
# 9
# 10
# T
# C
# i
# TC
# TAGC
# LP
# var head offset 8--0
# offsetapplicablepair == 10000000
# 2
# var T
# ref T
# var T
# ref C
# strvarsegment TT
# strrefsegment TC
# deleted comfirmation above. not same is good
# var next G
# ref next C
# var next G
# ref next T
# var next A
# ref next G
# var next C
# ref next G
# strnextvarsegment GGAC
# strnextrefsegment CTGG
# same segment comfirmation above, same is good
# strdel T
# ref T
# strdel C
# ref C
# correct deleted seq comfirmation above, same is good
# strins T
# var T
# strins A
# var T
# strins G
# var C
# strins C
# var T
# correct inserted seq comfirmation above, same is good
#
#
#  Variant#9 Variant:c.0021_0039inv##PP --- matched 9
# in rule verification 9 ----------------------c.0021_0039inv##PP
# 21
# 39
# PP
# var head offset 9--0
# offsetapplicablepair == 10000000
# 19
# GACAGGCTGTGGGGTTTCT
# AGAAACCCCACAGCCTGTC
# GACAGGCTGTGGGGTTTCT
# var A
# ref G
# var G
# ref A
# var A
# ref C
# var A
# ref A
# var A
# ref G
# var C
# ref G
# var C
# ref C
# var C
# ref T
# var C
# ref G
# var A
# ref T
# var C
# ref G
# var A
# ref G
# var G
# ref G
# var C
# ref G
# var C
# ref T
# var T
# ref T
# var G
# ref T
# var T
# ref C
# var C
# ref T
# strvarsegment which is inverted GACAGGCTGTGGGGTTTCT
# strvarsegment which is inverted back AGAAACCCCACAGCCTGTC
# strrefsegment GACAGGCTGTGGGGTTTCT
# inversion reverse complement comfirmation above, same [2 and 3] is good
# var next C
# ref next C
# var next A
# ref next A
# var next G
# ref next G
# var next A
# ref next A
# strnextvarsegment CAGA
# strnextrefsegment CAGA
# same segment comfirmation above, same is good
#
#
#  Variant#10 Variant:c.0021_0039con0061_0079##LP --- matched 10
# in rule verification 10 ----------------------c.0021_0039con0061_0079##LP
# 21
# 39
# 61
# 79
# LP
# var head offset 10--0
# offsetapplicablepair == 10000000
# FFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFF
# 19
# 19
# var G
# refcon T
# var A
# refcon C
# var C
# refcon A
# var A
# refcon G
# var G
# refcon G
# var G
# refcon A
# var C
# refcon G
# var T
# refcon G
# var G
# refcon C
# var T
# refcon C
# var G
# refcon T
# var G
# refcon T
# var G
# refcon C
# var G
# refcon A
# var T
# refcon C
# var T
# refcon C
# var T
# refcon C
# var C
# refcon T
# var T
# refcon C
# strvarsegment GACAGGCTGTGGGGTTTCT
# strrefsegment TCAGGAGGCCTTCACCCTC
# converted comfirmation above, i.e same [var, ref-con] is good
# var next C
# ref next C
# var next A
# ref next A
# var next G
# ref next G
# var next A
# ref next A
# strnextvarsegment CAGA
# strnextrefsegment CAGA
# same segment comfirmation above, same is good
#
#
#  Variant#11 Variant:c.0020G>T##BB --- matched 1
# in rule verification 1----------------------c.0020G>T##BB
# 20
# G
# T
# substitution confirmation 1
# BB
# var head offset 1--0
# offsetapplicablepair == 10000000
# G
# G
# substitution confirmation 2
#
#
#  Variant#12 Variant:c.0015_0018del##LB --- matched 2
# in rule verification 2----------------------c.0015_0018del##LB
# 15
# 18
# LB
# var head offset 2--0
# offsetapplicablepair == 10000000
# 4
# var A
# ref A
# var C
# ref C
# var G
# ref G
# var G
# ref G
# strvarsegment ACGG
# strrefsegment ACGG
# deletion comfirmation above, NOT same is good
# var next A
# ref next G
# var next C
# ref next G
# var next G
# ref next G
# var next G
# ref next A
# strnextvarsegment ACGG
# strnextrefsegment GGGA
# same segment confirmation above, same is good
#
#
#  Variant#13 Variant:c.0019_0022delGGGA##PP --- matched 3
# in rule verification 3----------------------c.0019_0022delGGGA##PP
# 19
# 22
# GGGA
# PP
# var head offset 3--0
# offsetapplicablepair == 10000000
# 4
# var G
# ref G
# var G
# ref G
# var G
# ref G
# var A
# ref A
# strvarsegment GGGA
# strrefsegment GGGA
# deletion comfirmation above, NOT same is good
# var next G
# ref next C
# var next G
# ref next A
# var next G
# ref next G
# var next A
# ref next G
# strnextvarsegment GGGA
# strnextrefsegment CAGG
# same segment comfirmation above, same is good
# strdel G
# ref G
# strdel G
# ref G
# strdel G
# ref G
# strdel A
# ref A
# right seq deleted comfirmation above, same is good
#
#
#  Variant#14 Variant:c.0019_0022dup##LP --- matched 4
# in rule verification 4----------------------c.0019_0022dup##LP
# 19
# 22
# LP
# var head offset 4--0
# offsetapplicablepair == 10000000
# 4
# var C
# ref G
# var A
# ref G
# var G
# ref G
# var G
# ref A
# strvarsegment CAGG
# strrefsegment GGGA
# duplication comfirmation above, same is good
# var next C
# ref next C
# var next T
# ref next A
# var next G
# ref next G
# var next T
# ref next G
# strnextvarsegment CTGT
# strnextrefsegment CAGG
# same segment comfirmation above, same is good
#
#
#  Variant#15 Variant:c.0023_0026dupCAGG##NN --- matched 5
# in rule verification 5----------------------c.0023_0026dupCAGG##NN
# 23
# 26
# CAGG
# NN
# var head offset 5--0
# offsetapplicablepair == 10000000
# 4
# var pos =  27
# var C
# ref pos =  23
# ref C
# var pos =  28
# var T
# ref pos =  24
# ref A
# var pos =  29
# var G
# ref pos =  25
# ref G
# var pos =  30
# var T
# ref pos =  26
# ref G
# strvarsegment CTGT
# strrefsegment CAGG
# duplication comfirmation above, same is good
# var next G
# ref next C
# var next G
# ref next T
# var next G
# ref next G
# var next G
# ref next T
# strnextvarsegment GGGG
# strnextrefsegment CTGT
# same segment comfirmation above, same is good
# strdup C
# ref C
# strdup A
# ref A
# strdup G
# ref G
# strdup G
# ref G
# correct duplicate seq comfirmation above, same is good
#
#
#  Variant#16 Variant:c.0022_0023insATATAT##BB --- matched 6
# in rule verification 6----------------------c.0022_0023insATATAT##BB
# 22
# 23
# ATATAT
# BB
# var head offset 6--0
# offsetapplicablepair == 10000000
# 2
# var C
# ref C
# var A
# ref A
# var G
# ref G
# var G
# ref G
# var C
# ref C
# var T
# ref T
# strvarsegment CAGGCT
# strrefsegment CAGGCT
# duplicated? why not inserted? comfirmation above, NOT same is good
# var next G
# ref next C
# var next T
# ref next A
# var next G
# ref next G
# var next G
# ref next G
# strnextvarsegment GTGG
# strnextrefsegment CAGG
# same segment comfirmation above, same is good
# strins A
# var C
# strins T
# var A
# strins A
# var G
# strins T
# var G
# strins A
# var C
# strins T
# var T
# correct inserted seq comfirmation above, same is good
#
#
#  Variant#17 Variant:c.0020_0021delinsCATG##LP --- matched 7
# in rule verification 7----------------------c.0020_0021delinsCATG##LP
# 20
# 21
# CATG
# LP
# var head offset 7--0
# offsetapplicablepair == 10000000
# 2
# var G
# ref G
# var G
# ref G
# strvarsegment GG
# strrefsegment GG
# deleted comfirmation above, not same is true
# var next A
# ref next A
# var next G
# ref next C
# var next G
# ref next A
# var next C
# ref next G
# strnextvarsegment AGGC
# strnextrefsegment ACAG
# same segment comfirmation above, same is good
# strdelins C
# var G
# strdelins A
# var G
# strdelins T
# var A
# strdelins G
# var C
# correct inserted seq comfirmation above, same is good
#
#
#  Variant#18 Variant:c.0019_0020delGGinsCAGT##LP --- matched 8
# in rule verification 8 ----------------------c.0019_0020delGGinsCAGT##LP
# 19
# 20
# G
# G
# i
# GG
# CAGT
# LP
# var head offset 8--0
# offsetapplicablepair == 10000000
# 2
# var G
# ref G
# var G
# ref G
# strvarsegment GG
# strrefsegment GG
# deleted comfirmation above. not same is good
# var next C
# ref next G
# var next A
# ref next A
# var next G
# ref next C
# var next G
# ref next A
# strnextvarsegment CAGG
# strnextrefsegment GACA
# same segment comfirmation above, same is good
# strdel G
# ref G
# strdel G
# ref G
# correct deleted seq comfirmation above, same is good
# strins C
# var G
# strins A
# var G
# strins G
# var G
# strins T
# var A
# correct inserted seq comfirmation above, same is good
#
#
#  Variant#19 Variant:c.0031_0049inv##PP --- matched 9
# in rule verification 9 ----------------------c.0031_0049inv##PP
# 31
# 49
# PP
# var head offset 9--0
# offsetapplicablepair == 10000000
# 19
# GGGGTTTCTCAGATAACTG
# CAGTTATCTGAGAAACCCC
# GGGGTTTCTCAGATAACTG
# var C
# ref G
# var A
# ref G
# var G
# ref G
# var T
# ref G
# var T
# ref T
# var A
# ref T
# var T
# ref T
# var C
# ref C
# var T
# ref T
# var G
# ref C
# var A
# ref A
# var G
# ref G
# var A
# ref A
# var A
# ref T
# var A
# ref A
# var C
# ref A
# var C
# ref C
# var C
# ref T
# var C
# ref G
# strvarsegment which is inverted GGGGTTTCTCAGATAACTG
# strvarsegment which is inverted back CAGTTATCTGAGAAACCCC
# strrefsegment GGGGTTTCTCAGATAACTG
# inversion reverse complement comfirmation above, same [2 and 3] is good
# var next G
# ref next G
# var next G
# ref next G
# var next C
# ref next C
# var next C
# ref next C
# strnextvarsegment GGCC
# strnextrefsegment GGCC
# same segment comfirmation above, same is good
#
#
#  Variant#20 Variant:c.0031_0049con0071_0089##LP --- matched 10
# in rule verification 10 ----------------------c.0031_0049con0071_0089##LP
# 31
# 49
# 71
# 89
# LP
# var head offset 10--0
# offsetapplicablepair == 10000000
# FFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFF
# 19
# 19
# var G
# refcon T
# var G
# refcon T
# var G
# refcon C
# var G
# refcon A
# var T
# refcon C
# var T
# refcon C
# var T
# refcon C
# var C
# refcon T
# var T
# refcon C
# var C
# refcon T
# var A
# refcon G
# var G
# refcon C
# var A
# refcon T
# var T
# refcon C
# var A
# refcon T
# var A
# refcon G
# var C
# refcon G
# var T
# refcon G
# var G
# refcon T
# strvarsegment GGGGTTTCTCAGATAACTG
# strrefsegment TTCACCCTCTGCTCTGGGT
# converted comfirmation above, i.e same [var, ref-con] is good
# var next G
# ref next G
# var next G
# ref next G
# var next C
# ref next C
# var next C
# ref next C
# strnextvarsegment GGCC
# strnextrefsegment GGCC
# same segment comfirmation above, same is good
#
#
#  Variant#21 Variant:c.0030T>A##BB --- matched 1
# in rule verification 1----------------------c.0030T>A##BB
# 30
# T
# A
# substitution confirmation 1
# BB
# var head offset 1--0
# offsetapplicablepair == 10000000
# T
# T
# substitution confirmation 2
#
#
#  Variant#22 Variant:c.0025_0028del##LB --- matched 2
# in rule verification 2----------------------c.0025_0028del##LB
# 25
# 28
# LB
# var head offset 2--0
# offsetapplicablepair == 10000000
# 4
# var G
# ref G
# var G
# ref G
# var C
# ref C
# var T
# ref T
# strvarsegment GGCT
# strrefsegment GGCT
# deletion comfirmation above, NOT same is good
# var next G
# ref next G
# var next G
# ref next T
# var next C
# ref next G
# var next T
# ref next G
# strnextvarsegment GGCT
# strnextrefsegment GTGG
# same segment confirmation above, same is good
#
#
#  Variant#23 Variant:c.0030_0033delTGGG##PP --- matched 3
# in rule verification 3----------------------c.0030_0033delTGGG##PP
# 30
# 33
# TGGG
# PP
# var head offset 3--0
# offsetapplicablepair == 10000000
# 4
# var T
# ref T
# var G
# ref G
# var G
# ref G
# var G
# ref G
# strvarsegment TGGG
# strrefsegment TGGG
# deletion comfirmation above, NOT same is good
# var next T
# ref next G
# var next G
# ref next T
# var next G
# ref next T
# var next G
# ref next T
# strnextvarsegment TGGG
# strnextrefsegment GTTT
# same segment comfirmation above, same is good
# strdel T
# ref T
# strdel G
# ref G
# strdel G
# ref G
# strdel G
# ref G
# right seq deleted comfirmation above, same is good
#
#
#  Variant#24 Variant:c.0029_0032dup##LP --- matched 4
# in rule verification 4----------------------c.0029_0032dup##LP
# 29
# 32
# LP
# var head offset 4--0
# offsetapplicablepair == 10000000
# 4
# var G
# ref G
# var G
# ref T
# var T
# ref G
# var T
# ref G
# strvarsegment GGTT
# strrefsegment GTGG
# duplication comfirmation above, same is good
# var next T
# ref next G
# var next C
# ref next G
# var next T
# ref next T
# var next C
# ref next T
# strnextvarsegment TCTC
# strnextrefsegment GGTT
# same segment comfirmation above, same is good
#
#
#  Variant#25 Variant:c.0040_0043dupCAGA##NN --- matched 5
# in rule verification 5----------------------c.0040_0043dupCAGA##NN
# 40
# 43
# CAGA
# NN
# var head offset 5--0
# offsetapplicablepair == 10000000
# 4
# var pos =  44
# var T
# ref pos =  40
# ref C
# var pos =  45
# var A
# ref pos =  41
# ref A
# var pos =  46
# var A
# ref pos =  42
# ref G
# var pos =  47
# var C
# ref pos =  43
# ref A
# strvarsegment TAAC
# strrefsegment CAGA
# duplication comfirmation above, same is good
# var next T
# ref next T
# var next G
# ref next A
# var next G
# ref next A
# var next G
# ref next C
# strnextvarsegment TGGG
# strnextrefsegment TAAC
# same segment comfirmation above, same is good
# strdup C
# ref C
# strdup A
# ref A
# strdup G
# ref G
# strdup A
# ref A
# correct duplicate seq comfirmation above, same is good
#
#
#  Variant#26 Variant:c.0032_0033insATATAT##BB --- matched 6
# in rule verification 6----------------------c.0032_0033insATATAT##BB
# 32
# 33
# ATATAT
# BB
# var head offset 6--0
# offsetapplicablepair == 10000000
# 2
# var G
# ref G
# var G
# ref G
# var T
# ref T
# var T
# ref T
# var T
# ref T
# var C
# ref C
# strvarsegment GGTTTC
# strrefsegment GGTTTC
# duplicated? why not inserted? comfirmation above, NOT same is good
# var next T
# ref next G
# var next C
# ref next G
# var next A
# ref next T
# var next G
# ref next T
# strnextvarsegment TCAG
# strnextrefsegment GGTT
# same segment comfirmation above, same is good
# strins A
# var G
# strins T
# var G
# strins A
# var T
# strins T
# var T
# strins A
# var T
# strins T
# var C
# correct inserted seq comfirmation above, same is good
#
#
#  Variant#27 Variant:c.0029_0030delinsGGAA##LP --- matched 7
# in rule verification 7----------------------c.0029_0030delinsGGAA##LP
# 29
# 30
# GGAA
# LP
# var head offset 7--0
# offsetapplicablepair == 10000000
# 2
# var G
# ref G
# var T
# ref T
# strvarsegment GT
# strrefsegment GT
# deleted comfirmation above, not same is true
# var next G
# ref next G
# var next G
# ref next G
# var next T
# ref next G
# var next T
# ref next G
# strnextvarsegment GGTT
# strnextrefsegment GGGG
# same segment comfirmation above, same is good
# strdelins G
# var G
# strdelins G
# var T
# strdelins A
# var G
# strdelins A
# var G
# correct inserted seq comfirmation above, same is good
#
#
#  Variant#28 Variant:c.0029_0030delGTinsCCTT##LP --- matched 8
# in rule verification 8 ----------------------c.0029_0030delGTinsCCTT##LP
# 29
# 30
# G
# T
# i
# GT
# CCTT
# LP
# var head offset 8--0
# offsetapplicablepair == 10000000
# 2
# var G
# ref G
# var T
# ref T
# strvarsegment GT
# strrefsegment GT
# deleted comfirmation above. not same is good
# var next G
# ref next G
# var next G
# ref next G
# var next T
# ref next G
# var next T
# ref next G
# strnextvarsegment GGTT
# strnextrefsegment GGGG
# same segment comfirmation above, same is good
# strdel G
# ref G
# strdel T
# ref T
# correct deleted seq comfirmation above, same is good
# strins C
# var G
# strins C
# var T
# strins T
# var G
# strins T
# var G
# correct inserted seq comfirmation above, same is good
#
#
#  Variant#29 Variant:c.0041_0059inv##PP --- matched 9
# in rule verification 9 ----------------------c.0041_0059inv##PP
# 41
# 59
# PP
# var head offset 9--0
# offsetapplicablepair == 10000000
# 19
# AGATAACTGGGCCCCTGCG
# CGCAGGGGCCCAGTTATCT
# AGATAACTGGGCCCCTGCG
# var C
# ref A
# var G
# ref G
# var C
# ref A
# var A
# ref T
# var G
# ref A
# var G
# ref A
# var G
# ref C
# var G
# ref T
# var C
# ref G
# var C
# ref G
# var C
# ref G
# var A
# ref C
# var G
# ref C
# var T
# ref C
# var T
# ref C
# var A
# ref T
# var T
# ref G
# var C
# ref C
# var T
# ref G
# strvarsegment which is inverted AGATAACTGGGCCCCTGCG
# strvarsegment which is inverted back CGCAGGGGCCCAGTTATCT
# strrefsegment AGATAACTGGGCCCCTGCG
# inversion reverse complement comfirmation above, same [2 and 3] is good
# var next C
# ref next C
# var next T
# ref next T
# var next C
# ref next C
# var next A
# ref next A
# strnextvarsegment CTCA
# strnextrefsegment CTCA
# same segment comfirmation above, same is good
#
#
#  Variant#30 Variant:c.0041_0059con0081_0099##LP --- matched 10
# in rule verification 10 ----------------------c.0041_0059con0081_0099##LP
# 41
# 59
# 81
# 99
# LP
# var head offset 10--0
# offsetapplicablepair == 10000000
# FFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFF
# 19
# 19
# var A
# refcon G
# var G
# refcon C
# var A
# refcon T
# var T
# refcon C
# var A
# refcon T
# var A
# refcon G
# var C
# refcon G
# var T
# refcon G
# var G
# refcon T
# var G
# refcon A
# var G
# refcon A
# var C
# refcon A
# var C
# refcon G
# var C
# refcon T
# var C
# refcon T
# var T
# refcon C
# var G
# refcon A
# var C
# refcon T
# var G
# refcon T
# strvarsegment AGATAACTGGGCCCCTGCG
# strrefsegment GCTCTGGGTAAAGTTCATT
# converted comfirmation above, i.e same [var, ref-con] is good
# var next C
# ref next C
# var next T
# ref next T
# var next C
# ref next C
# var next A
# ref next A
# strnextvarsegment CTCA
# strnextrefsegment CTCA
# same segment comfirmation above, same is good
# 1 -- P001-BRCA1-VAR02.fasta
#
#
#  Variant#1 Variant:c.0010C>T##BB --- matched 1
# in rule verification 1----------------------c.0010C>T##BB
# 10
# C
# T
# substitution confirmation 1
# BB
# var head offset 1--0
# offsetapplicablepair == 10000000
# G
# C
# substitution confirmation 2
#
#
#  Variant#2 Variant:c.0005_0008del##LB --- matched 2
# in rule verification 2----------------------c.0005_0008del##LB
# 5
# 8
# LB
# var head offset 2--0
# offsetapplicablepair == 10000000
# 4
# var T
# ref G
# var C
# ref A
# var C
# ref C
# var T
# ref T
# strvarsegment TCCT
# strrefsegment GACT
# deletion comfirmation above, NOT same is good
# var next T
# ref next T
# var next C
# ref next C
# var next C
# ref next C
# var next T
# ref next T
# strnextvarsegment TCCT
# strnextrefsegment TCCT
# same segment confirmation above, same is good
# c.0005_0008del##LB      PRESENT                              ******************
# new var head offset ---4
# new offsetapplicablepair == 5
#
#
#  Variant#3 Variant:c.0009_0012delTCCT##PP --- matched 3
# in rule verification 3----------------------c.0009_0012delTCCT##PP
# 9
# 12
# TCCT
# PP
# var head offset 3---4
# offsetapplicablepair == 5
# 4
# var T
# ref T
# var C
# ref C
# var C
# ref C
# var T
# ref T
# strvarsegment TCCT
# strrefsegment TCCT
# deletion comfirmation above, NOT same is good
# var next T
# ref next G
# var next C
# ref next G
# var next C
# ref next A
# var next T
# ref next C
# strnextvarsegment TCCT
# strnextrefsegment GGAC
# same segment comfirmation above, same is good
# strdel T
# ref T
# strdel C
# ref C
# strdel C
# ref C
# strdel T
# ref T
# right seq deleted comfirmation above, same is good
#
#
#  Variant#4 Variant:c.0009_0012dup##LP --- matched 4
# in rule verification 4----------------------c.0009_0012dup##LP
# 9
# 12
# LP
# var head offset 4---4
# offsetapplicablepair == 5
# 4
# var G
# ref T
# var G
# ref C
# var A
# ref C
# var C
# ref T
# strvarsegment GGAC
# strrefsegment TCCT
# duplication comfirmation above, same is good
# var next G
# ref next G
# var next G
# ref next G
# var next G
# ref next A
# var next G
# ref next C
# strnextvarsegment GGGG
# strnextrefsegment GGAC
# same segment comfirmation above, same is good
#
#
#  Variant#5 Variant:c.0014_0017dupGACG##NN --- matched 5
# in rule verification 5----------------------c.0014_0017dupGACG##NN
# 14
# 17
# GACG
# NN
# var head offset 5---4
# offsetapplicablepair == 5
# 4
# var pos =  14
# var G
# ref pos =  14
# ref G
# var pos =  15
# var G
# ref pos =  15
# ref A
# var pos =  16
# var G
# ref pos =  16
# ref C
# var pos =  17
# var G
# ref pos =  17
# ref G
# strvarsegment GGGG
# strrefsegment GACG
# duplication comfirmation above, same is good
# var next A
# ref next G
# var next C
# ref next G
# var next A
# ref next G
# var next G
# ref next G
# strnextvarsegment ACAG
# strnextrefsegment GGGG
# same segment comfirmation above, same is good
# strdup G
# ref G
# strdup A
# ref A
# strdup C
# ref C
# strdup G
# ref G
# correct duplicate seq comfirmation above, same is good
#
#
#  Variant#6 Variant:c.0012_0013insATATAT##BB --- matched 6
# in rule verification 6----------------------c.0012_0013insATATAT##BB
# 12
# 13
# ATATAT
# BB
# var head offset 6---4
# offsetapplicablepair == 5
# 2
# var G
# ref G
# var G
# ref G
# var A
# ref A
# var C
# ref C
# var G
# ref G
# var G
# ref G
# strvarsegment GGACGG
# strrefsegment GGACGG
# duplicated? why not inserted? comfirmation above, NOT same is good
# var next G
# ref next G
# var next G
# ref next G
# var next G
# ref next A
# var next A
# ref next C
# strnextvarsegment GGGA
# strnextrefsegment GGAC
# same segment comfirmation above, same is good
# strins A
# var G
# strins T
# var G
# strins A
# var G
# strins T
# var G
# strins A
# var G
# strins T
# var A
# correct inserted seq comfirmation above, same is good
#
#
#  Variant#7 Variant:c.0009_0010delinsGGAA##LP --- matched 7
# in rule verification 7----------------------c.0009_0010delinsGGAA##LP
# 9
# 10
# GGAA
# LP
# var head offset 7---4
# offsetapplicablepair == 5
# 2
# var T
# ref T
# var C
# ref C
# strvarsegment TC
# strrefsegment TC
# deleted comfirmation above, not same is true
# var next G
# ref next C
# var next G
# ref next T
# var next A
# ref next G
# var next C
# ref next G
# strnextvarsegment GGAC
# strnextrefsegment CTGG
# same segment comfirmation above, same is good
# strdelins G
# var G
# strdelins G
# var G
# strdelins A
# var A
# strdelins A
# var C
# correct inserted seq comfirmation above, same is good
#
#
#  Variant#8 Variant:c.0009_0010delTCinsTAGC##LP --- matched 8
# in rule verification 8 ----------------------c.0009_0010delTCinsTAGC##LP
# 9
# 10
# T
# C
# i
# TC
# TAGC
# LP
# var head offset 8---4
# offsetapplicablepair == 5
# 2
# var T
# ref T
# var C
# ref C
# strvarsegment TC
# strrefsegment TC
# deleted comfirmation above. not same is good
# var next G
# ref next C
# var next G
# ref next T
# var next A
# ref next G
# var next C
# ref next G
# strnextvarsegment GGAC
# strnextrefsegment CTGG
# same segment comfirmation above, same is good
# strdel T
# ref T
# strdel C
# ref C
# correct deleted seq comfirmation above, same is good
# strins T
# var G
# strins A
# var G
# strins G
# var A
# strins C
# var C
# correct inserted seq comfirmation above, same is good
#
#
#  Variant#9 Variant:c.0021_0039inv##PP --- matched 9
# in rule verification 9 ----------------------c.0021_0039inv##PP
# 21
# 39
# PP
# var head offset 9---4
# offsetapplicablepair == 5
# 19
# GACAGGCTGTGGGGTTTCT
# AGAAACCCCACAGCCTGTC
# GACAGGCTGTGGGGTTTCT
# var A
# ref G
# var G
# ref A
# var A
# ref C
# var A
# ref A
# var A
# ref G
# var C
# ref G
# var C
# ref C
# var C
# ref T
# var C
# ref G
# var A
# ref T
# var C
# ref G
# var A
# ref G
# var G
# ref G
# var C
# ref G
# var C
# ref T
# var T
# ref T
# var G
# ref T
# var T
# ref C
# var C
# ref T
# strvarsegment which is inverted GACAGGCTGTGGGGTTTCT
# strvarsegment which is inverted back AGAAACCCCACAGCCTGTC
# strrefsegment GACAGGCTGTGGGGTTTCT
# inversion reverse complement comfirmation above, same [2 and 3] is good
# var next C
# ref next C
# var next A
# ref next A
# var next G
# ref next G
# var next A
# ref next A
# strnextvarsegment CAGA
# strnextrefsegment CAGA
# same segment comfirmation above, same is good
#
#
#  Variant#10 Variant:c.0021_0039con0061_0079##LP --- matched 10
# in rule verification 10 ----------------------c.0021_0039con0061_0079##LP
# 21
# 39
# 61
# 79
# LP
# var head offset 10---4
# offsetapplicablepair == 5
# FFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFF
# 19
# 19
# var G
# refcon T
# var A
# refcon C
# var C
# refcon A
# var A
# refcon G
# var G
# refcon G
# var G
# refcon A
# var C
# refcon G
# var T
# refcon G
# var G
# refcon C
# var T
# refcon C
# var G
# refcon T
# var G
# refcon T
# var G
# refcon C
# var G
# refcon A
# var T
# refcon C
# var T
# refcon C
# var T
# refcon C
# var C
# refcon T
# var T
# refcon C
# strvarsegment GACAGGCTGTGGGGTTTCT
# strrefsegment TCAGGAGGCCTTCACCCTC
# converted comfirmation above, i.e same [var, ref-con] is good
# var next C
# ref next C
# var next A
# ref next A
# var next G
# ref next G
# var next A
# ref next A
# strnextvarsegment CAGA
# strnextrefsegment CAGA
# same segment comfirmation above, same is good
#
#
#  Variant#11 Variant:c.0020G>T##BB --- matched 1
# in rule verification 1----------------------c.0020G>T##BB
# 20
# G
# T
# substitution confirmation 1
# BB
# var head offset 1---4
# offsetapplicablepair == 5
# G
# G
# substitution confirmation 2
#
#
#  Variant#12 Variant:c.0015_0018del##LB --- matched 2
# in rule verification 2----------------------c.0015_0018del##LB
# 15
# 18
# LB
# var head offset 2---4
# offsetapplicablepair == 5
# 4
# var A
# ref A
# var C
# ref C
# var G
# ref G
# var G
# ref G
# strvarsegment ACGG
# strrefsegment ACGG
# deletion comfirmation above, NOT same is good
# var next A
# ref next G
# var next C
# ref next G
# var next G
# ref next G
# var next G
# ref next A
# strnextvarsegment ACGG
# strnextrefsegment GGGA
# same segment confirmation above, same is good
#
#
#  Variant#13 Variant:c.0019_0022delGGGA##PP --- matched 3
# in rule verification 3----------------------c.0019_0022delGGGA##PP
# 19
# 22
# GGGA
# PP
# var head offset 3---4
# offsetapplicablepair == 5
# 4
# var G
# ref G
# var G
# ref G
# var G
# ref G
# var A
# ref A
# strvarsegment GGGA
# strrefsegment GGGA
# deletion comfirmation above, NOT same is good
# var next G
# ref next C
# var next G
# ref next A
# var next G
# ref next G
# var next A
# ref next G
# strnextvarsegment GGGA
# strnextrefsegment CAGG
# same segment comfirmation above, same is good
# strdel G
# ref G
# strdel G
# ref G
# strdel G
# ref G
# strdel A
# ref A
# right seq deleted comfirmation above, same is good
#
#
#  Variant#14 Variant:c.0019_0022dup##LP --- matched 4
# in rule verification 4----------------------c.0019_0022dup##LP
# 19
# 22
# LP
# var head offset 4---4
# offsetapplicablepair == 5
# 4
# var C
# ref G
# var A
# ref G
# var G
# ref G
# var G
# ref A
# strvarsegment CAGG
# strrefsegment GGGA
# duplication comfirmation above, same is good
# var next C
# ref next C
# var next T
# ref next A
# var next G
# ref next G
# var next T
# ref next G
# strnextvarsegment CTGT
# strnextrefsegment CAGG
# same segment comfirmation above, same is good
#
#
#  Variant#15 Variant:c.0023_0026dupCAGG##NN --- matched 5
# in rule verification 5----------------------c.0023_0026dupCAGG##NN
# 23
# 26
# CAGG
# NN
# var head offset 5---4
# offsetapplicablepair == 5
# 4
# var pos =  23
# var C
# ref pos =  23
# ref C
# var pos =  24
# var T
# ref pos =  24
# ref A
# var pos =  25
# var G
# ref pos =  25
# ref G
# var pos =  26
# var T
# ref pos =  26
# ref G
# strvarsegment CTGT
# strrefsegment CAGG
# duplication comfirmation above, same is good
# var next G
# ref next C
# var next G
# ref next T
# var next G
# ref next G
# var next G
# ref next T
# strnextvarsegment GGGG
# strnextrefsegment CTGT
# same segment comfirmation above, same is good
# strdup C
# ref C
# strdup A
# ref A
# strdup G
# ref G
# strdup G
# ref G
# correct duplicate seq comfirmation above, same is good
#
#
#  Variant#16 Variant:c.0022_0023insATATAT##BB --- matched 6
# in rule verification 6----------------------c.0022_0023insATATAT##BB
# 22
# 23
# ATATAT
# BB
# var head offset 6---4
# offsetapplicablepair == 5
# 2
# var C
# ref C
# var A
# ref A
# var G
# ref G
# var G
# ref G
# var C
# ref C
# var T
# ref T
# strvarsegment CAGGCT
# strrefsegment CAGGCT
# duplicated? why not inserted? comfirmation above, NOT same is good
# var next G
# ref next C
# var next T
# ref next A
# var next G
# ref next G
# var next G
# ref next G
# strnextvarsegment GTGG
# strnextrefsegment CAGG
# same segment comfirmation above, same is good
# strins A
# var C
# strins T
# var T
# strins A
# var G
# strins T
# var T
# strins A
# var G
# strins T
# var G
# correct inserted seq comfirmation above, same is good
#
#
#  Variant#17 Variant:c.0020_0021delinsCATG##LP --- matched 7
# in rule verification 7----------------------c.0020_0021delinsCATG##LP
# 20
# 21
# CATG
# LP
# var head offset 7---4
# offsetapplicablepair == 5
# 2
# var G
# ref G
# var G
# ref G
# strvarsegment GG
# strrefsegment GG
# deleted comfirmation above, not same is true
# var next A
# ref next A
# var next G
# ref next C
# var next G
# ref next A
# var next C
# ref next G
# strnextvarsegment AGGC
# strnextrefsegment ACAG
# same segment comfirmation above, same is good
# strdelins C
# var A
# strdelins A
# var G
# strdelins T
# var G
# strdelins G
# var C
# correct inserted seq comfirmation above, same is good
#
#
#  Variant#18 Variant:c.0019_0020delGGinsCAGT##LP --- matched 8
# in rule verification 8 ----------------------c.0019_0020delGGinsCAGT##LP
# 19
# 20
# G
# G
# i
# GG
# CAGT
# LP
# var head offset 8---4
# offsetapplicablepair == 5
# 2
# var G
# ref G
# var G
# ref G
# strvarsegment GG
# strrefsegment GG
# deleted comfirmation above. not same is good
# var next C
# ref next G
# var next A
# ref next A
# var next G
# ref next C
# var next G
# ref next A
# strnextvarsegment CAGG
# strnextrefsegment GACA
# same segment comfirmation above, same is good
# strdel G
# ref G
# strdel G
# ref G
# correct deleted seq comfirmation above, same is good
# strins C
# var C
# strins A
# var A
# strins G
# var G
# strins T
# var G
# correct inserted seq comfirmation above, same is good
#
#
#  Variant#19 Variant:c.0031_0049inv##PP --- matched 9
# in rule verification 9 ----------------------c.0031_0049inv##PP
# 31
# 49
# PP
# var head offset 9---4
# offsetapplicablepair == 5
# 19
# GGGGTTTCTCAGATAACTG
# CAGTTATCTGAGAAACCCC
# GGGGTTTCTCAGATAACTG
# var C
# ref G
# var A
# ref G
# var G
# ref G
# var T
# ref G
# var T
# ref T
# var A
# ref T
# var T
# ref T
# var C
# ref C
# var T
# ref T
# var G
# ref C
# var A
# ref A
# var G
# ref G
# var A
# ref A
# var A
# ref T
# var A
# ref A
# var C
# ref A
# var C
# ref C
# var C
# ref T
# var C
# ref G
# strvarsegment which is inverted GGGGTTTCTCAGATAACTG
# strvarsegment which is inverted back CAGTTATCTGAGAAACCCC
# strrefsegment GGGGTTTCTCAGATAACTG
# inversion reverse complement comfirmation above, same [2 and 3] is good
# var next G
# ref next G
# var next G
# ref next G
# var next C
# ref next C
# var next C
# ref next C
# strnextvarsegment GGCC
# strnextrefsegment GGCC
# same segment comfirmation above, same is good
#
#
#  Variant#20 Variant:c.0031_0049con0071_0089##LP --- matched 10
# in rule verification 10 ----------------------c.0031_0049con0071_0089##LP
# 31
# 49
# 71
# 89
# LP
# var head offset 10---4
# offsetapplicablepair == 5
# FFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFF
# 19
# 19
# var G
# refcon T
# var G
# refcon T
# var G
# refcon C
# var G
# refcon A
# var T
# refcon C
# var T
# refcon C
# var T
# refcon C
# var C
# refcon T
# var T
# refcon C
# var C
# refcon T
# var A
# refcon G
# var G
# refcon C
# var A
# refcon T
# var T
# refcon C
# var A
# refcon T
# var A
# refcon G
# var C
# refcon G
# var T
# refcon G
# var G
# refcon T
# strvarsegment GGGGTTTCTCAGATAACTG
# strrefsegment TTCACCCTCTGCTCTGGGT
# converted comfirmation above, i.e same [var, ref-con] is good
# var next G
# ref next G
# var next G
# ref next G
# var next C
# ref next C
# var next C
# ref next C
# strnextvarsegment GGCC
# strnextrefsegment GGCC
# same segment comfirmation above, same is good
#
#
#  Variant#21 Variant:c.0030T>A##BB --- matched 1
# in rule verification 1----------------------c.0030T>A##BB
# 30
# T
# A
# substitution confirmation 1
# BB
# var head offset 1---4
# offsetapplicablepair == 5
# T
# T
# substitution confirmation 2
#
#
#  Variant#22 Variant:c.0025_0028del##LB --- matched 2
# in rule verification 2----------------------c.0025_0028del##LB
# 25
# 28
# LB
# var head offset 2---4
# offsetapplicablepair == 5
# 4
# var G
# ref G
# var G
# ref G
# var C
# ref C
# var T
# ref T
# strvarsegment GGCT
# strrefsegment GGCT
# deletion comfirmation above, NOT same is good
# var next G
# ref next G
# var next G
# ref next T
# var next C
# ref next G
# var next T
# ref next G
# strnextvarsegment GGCT
# strnextrefsegment GTGG
# same segment confirmation above, same is good
#
#
#  Variant#23 Variant:c.0030_0033delTGGG##PP --- matched 3
# in rule verification 3----------------------c.0030_0033delTGGG##PP
# 30
# 33
# TGGG
# PP
# var head offset 3---4
# offsetapplicablepair == 5
# 4
# var T
# ref T
# var G
# ref G
# var G
# ref G
# var G
# ref G
# strvarsegment TGGG
# strrefsegment TGGG
# deletion comfirmation above, NOT same is good
# var next T
# ref next G
# var next G
# ref next T
# var next G
# ref next T
# var next G
# ref next T
# strnextvarsegment TGGG
# strnextrefsegment GTTT
# same segment comfirmation above, same is good
# strdel T
# ref T
# strdel G
# ref G
# strdel G
# ref G
# strdel G
# ref G
# right seq deleted comfirmation above, same is good
#
#
#  Variant#24 Variant:c.0029_0032dup##LP --- matched 4
# in rule verification 4----------------------c.0029_0032dup##LP
# 29
# 32
# LP
# var head offset 4---4
# offsetapplicablepair == 5
# 4
# var G
# ref G
# var G
# ref T
# var T
# ref G
# var T
# ref G
# strvarsegment GGTT
# strrefsegment GTGG
# duplication comfirmation above, same is good
# var next T
# ref next G
# var next C
# ref next G
# var next T
# ref next T
# var next C
# ref next T
# strnextvarsegment TCTC
# strnextrefsegment GGTT
# same segment comfirmation above, same is good
#
#
#  Variant#25 Variant:c.0040_0043dupCAGA##NN --- matched 5
# in rule verification 5----------------------c.0040_0043dupCAGA##NN
# 40
# 43
# CAGA
# NN
# var head offset 5---4
# offsetapplicablepair == 5
# 4
# var pos =  40
# var T
# ref pos =  40
# ref C
# var pos =  41
# var A
# ref pos =  41
# ref A
# var pos =  42
# var A
# ref pos =  42
# ref G
# var pos =  43
# var C
# ref pos =  43
# ref A
# strvarsegment TAAC
# strrefsegment CAGA
# duplication comfirmation above, same is good
# var next T
# ref next T
# var next G
# ref next A
# var next G
# ref next A
# var next G
# ref next C
# strnextvarsegment TGGG
# strnextrefsegment TAAC
# same segment comfirmation above, same is good
# strdup C
# ref C
# strdup A
# ref A
# strdup G
# ref G
# strdup A
# ref A
# correct duplicate seq comfirmation above, same is good
#
#
#  Variant#26 Variant:c.0032_0033insATATAT##BB --- matched 6
# in rule verification 6----------------------c.0032_0033insATATAT##BB
# 32
# 33
# ATATAT
# BB
# var head offset 6---4
# offsetapplicablepair == 5
# 2
# var G
# ref G
# var G
# ref G
# var T
# ref T
# var T
# ref T
# var T
# ref T
# var C
# ref C
# strvarsegment GGTTTC
# strrefsegment GGTTTC
# duplicated? why not inserted? comfirmation above, NOT same is good
# var next T
# ref next G
# var next C
# ref next G
# var next A
# ref next T
# var next G
# ref next T
# strnextvarsegment TCAG
# strnextrefsegment GGTT
# same segment comfirmation above, same is good
# strins A
# var T
# strins T
# var C
# strins A
# var T
# strins T
# var C
# strins A
# var A
# strins T
# var G
# correct inserted seq comfirmation above, same is good
#
#
#  Variant#27 Variant:c.0029_0030delinsGGAA##LP --- matched 7
# in rule verification 7----------------------c.0029_0030delinsGGAA##LP
# 29
# 30
# GGAA
# LP
# var head offset 7---4
# offsetapplicablepair == 5
# 2
# var G
# ref G
# var T
# ref T
# strvarsegment GT
# strrefsegment GT
# deleted comfirmation above, not same is true
# var next G
# ref next G
# var next G
# ref next G
# var next T
# ref next G
# var next T
# ref next G
# strnextvarsegment GGTT
# strnextrefsegment GGGG
# same segment comfirmation above, same is good
# strdelins G
# var G
# strdelins G
# var G
# strdelins A
# var T
# strdelins A
# var T
# correct inserted seq comfirmation above, same is good
#
#
#  Variant#28 Variant:c.0029_0030delGTinsCCTT##LP --- matched 8
# in rule verification 8 ----------------------c.0029_0030delGTinsCCTT##LP
# 29
# 30
# G
# T
# i
# GT
# CCTT
# LP
# var head offset 8---4
# offsetapplicablepair == 5
# 2
# var G
# ref G
# var T
# ref T
# strvarsegment GT
# strrefsegment GT
# deleted comfirmation above. not same is good
# var next G
# ref next G
# var next G
# ref next G
# var next T
# ref next G
# var next T
# ref next G
# strnextvarsegment GGTT
# strnextrefsegment GGGG
# same segment comfirmation above, same is good
# strdel G
# ref G
# strdel T
# ref T
# correct deleted seq comfirmation above, same is good
# strins C
# var G
# strins C
# var G
# strins T
# var T
# strins T
# var T
# correct inserted seq comfirmation above, same is good
#
#
#  Variant#29 Variant:c.0041_0059inv##PP --- matched 9
# in rule verification 9 ----------------------c.0041_0059inv##PP
# 41
# 59
# PP
# var head offset 9---4
# offsetapplicablepair == 5
# 19
# AGATAACTGGGCCCCTGCG
# CGCAGGGGCCCAGTTATCT
# AGATAACTGGGCCCCTGCG
# var C
# ref A
# var G
# ref G
# var C
# ref A
# var A
# ref T
# var G
# ref A
# var G
# ref A
# var G
# ref C
# var G
# ref T
# var C
# ref G
# var C
# ref G
# var C
# ref G
# var A
# ref C
# var G
# ref C
# var T
# ref C
# var T
# ref C
# var A
# ref T
# var T
# ref G
# var C
# ref C
# var T
# ref G
# strvarsegment which is inverted AGATAACTGGGCCCCTGCG
# strvarsegment which is inverted back CGCAGGGGCCCAGTTATCT
# strrefsegment AGATAACTGGGCCCCTGCG
# inversion reverse complement comfirmation above, same [2 and 3] is good
# var next C
# ref next C
# var next T
# ref next T
# var next C
# ref next C
# var next A
# ref next A
# strnextvarsegment CTCA
# strnextrefsegment CTCA
# same segment comfirmation above, same is good
#
#
#  Variant#30 Variant:c.0041_0059con0081_0099##LP --- matched 10
# in rule verification 10 ----------------------c.0041_0059con0081_0099##LP
# 41
# 59
# 81
# 99
# LP
# var head offset 10---4
# offsetapplicablepair == 5
# FFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFF
# 19
# 19
# var A
# refcon G
# var G
# refcon C
# var A
# refcon T
# var T
# refcon C
# var A
# refcon T
# var A
# refcon G
# var C
# refcon G
# var T
# refcon G
# var G
# refcon T
# var G
# refcon A
# var G
# refcon A
# var C
# refcon A
# var C
# refcon G
# var C
# refcon T
# var C
# refcon T
# var T
# refcon C
# var G
# refcon A
# var C
# refcon T
# var G
# refcon T
# strvarsegment AGATAACTGGGCCCCTGCG
# strrefsegment GCTCTGGGTAAAGTTCATT
# converted comfirmation above, i.e same [var, ref-con] is good
# var next C
# ref next C
# var next T
# ref next T
# var next C
# ref next C
# var next A
# ref next A
# strnextvarsegment CTCA
# strnextrefsegment CTCA
# same segment comfirmation above, same is good
# 2 -- P001-BRCA1-VAR03.fasta
#
#
#  Variant#1 Variant:c.0010C>T##BB --- matched 1
# in rule verification 1----------------------c.0010C>T##BB
# 10
# C
# T
# substitution confirmation 1
# BB
# var head offset 1--0
# offsetapplicablepair == 5
# G
# C
# substitution confirmation 2
#
#
#  Variant#2 Variant:c.0005_0008del##LB --- matched 2
# in rule verification 2----------------------c.0005_0008del##LB
# 5
# 8
# LB
# var head offset 2--0
# offsetapplicablepair == 5
# 4
# var G
# ref G
# var A
# ref A
# var C
# ref C
# var T
# ref T
# strvarsegment GACT
# strrefsegment GACT
# deletion comfirmation above, NOT same is good
# var next G
# ref next T
# var next A
# ref next C
# var next C
# ref next C
# var next T
# ref next T
# strnextvarsegment GACT
# strnextrefsegment TCCT
# same segment confirmation above, same is good
#
#
#  Variant#3 Variant:c.0009_0012delTCCT##PP --- matched 3
# in rule verification 3----------------------c.0009_0012delTCCT##PP
# 9
# 12
# TCCT
# PP
# var head offset 3--0
# offsetapplicablepair == 5
# 4
# var G
# ref T
# var G
# ref C
# var A
# ref C
# var C
# ref T
# strvarsegment GGAC
# strrefsegment TCCT
# deletion comfirmation above, NOT same is good
# var next G
# ref next G
# var next G
# ref next G
# var next A
# ref next A
# var next C
# ref next C
# strnextvarsegment GGAC
# strnextrefsegment GGAC
# same segment comfirmation above, same is good
# strdel T
# ref T
# strdel C
# ref C
# strdel C
# ref C
# strdel T
# ref T
# right seq deleted comfirmation above, same is good
# c.0009_0012delTCCT##PP      PRESENT                                ******************
# new var head offset ---4
# new offsetapplicablepair == 5
#
#
#  Variant#4 Variant:c.0009_0012dup##LP --- matched 4
# in rule verification 4----------------------c.0009_0012dup##LP
# 9
# 12
# LP
# var head offset 4---4
# offsetapplicablepair == 5
# 4
# var G
# ref T
# var G
# ref C
# var A
# ref C
# var C
# ref T
# strvarsegment GGAC
# strrefsegment TCCT
# duplication comfirmation above, same is good
# var next G
# ref next G
# var next G
# ref next G
# var next G
# ref next A
# var next G
# ref next C
# strnextvarsegment GGGG
# strnextrefsegment GGAC
# same segment comfirmation above, same is good
#
#
#  Variant#5 Variant:c.0014_0017dupGACG##NN --- matched 5
# in rule verification 5----------------------c.0014_0017dupGACG##NN
# 14
# 17
# GACG
# NN
# var head offset 5---4
# offsetapplicablepair == 5
# 4
# var pos =  14
# var G
# ref pos =  14
# ref G
# var pos =  15
# var G
# ref pos =  15
# ref A
# var pos =  16
# var G
# ref pos =  16
# ref C
# var pos =  17
# var G
# ref pos =  17
# ref G
# strvarsegment GGGG
# strrefsegment GACG
# duplication comfirmation above, same is good
# var next A
# ref next G
# var next C
# ref next G
# var next A
# ref next G
# var next G
# ref next G
# strnextvarsegment ACAG
# strnextrefsegment GGGG
# same segment comfirmation above, same is good
# strdup G
# ref G
# strdup A
# ref A
# strdup C
# ref C
# strdup G
# ref G
# correct duplicate seq comfirmation above, same is good
#
#
#  Variant#6 Variant:c.0012_0013insATATAT##BB --- matched 6
# in rule verification 6----------------------c.0012_0013insATATAT##BB
# 12
# 13
# ATATAT
# BB
# var head offset 6---4
# offsetapplicablepair == 5
# 2
# var G
# ref G
# var G
# ref G
# var A
# ref A
# var C
# ref C
# var G
# ref G
# var G
# ref G
# strvarsegment GGACGG
# strrefsegment GGACGG
# duplicated? why not inserted? comfirmation above, NOT same is good
# var next G
# ref next G
# var next G
# ref next G
# var next G
# ref next A
# var next A
# ref next C
# strnextvarsegment GGGA
# strnextrefsegment GGAC
# same segment comfirmation above, same is good
# strins A
# var G
# strins T
# var G
# strins A
# var G
# strins T
# var G
# strins A
# var G
# strins T
# var A
# correct inserted seq comfirmation above, same is good
#
#
#  Variant#7 Variant:c.0009_0010delinsGGAA##LP --- matched 7
# in rule verification 7----------------------c.0009_0010delinsGGAA##LP
# 9
# 10
# GGAA
# LP
# var head offset 7---4
# offsetapplicablepair == 5
# 2
# var G
# ref T
# var A
# ref C
# strvarsegment GA
# strrefsegment TC
# deleted comfirmation above, not same is true
# var next G
# ref next C
# var next G
# ref next T
# var next A
# ref next G
# var next C
# ref next G
# strnextvarsegment GGAC
# strnextrefsegment CTGG
# same segment comfirmation above, same is good
# strdelins G
# var G
# strdelins G
# var G
# strdelins A
# var A
# strdelins A
# var C
# correct inserted seq comfirmation above, same is good
#
#
#  Variant#8 Variant:c.0009_0010delTCinsTAGC##LP --- matched 8
# in rule verification 8 ----------------------c.0009_0010delTCinsTAGC##LP
# 9
# 10
# T
# C
# i
# TC
# TAGC
# LP
# var head offset 8---4
# offsetapplicablepair == 5
# 2
# var G
# ref T
# var A
# ref C
# strvarsegment GA
# strrefsegment TC
# deleted comfirmation above. not same is good
# var next G
# ref next C
# var next G
# ref next T
# var next A
# ref next G
# var next C
# ref next G
# strnextvarsegment GGAC
# strnextrefsegment CTGG
# same segment comfirmation above, same is good
# strdel T
# ref T
# strdel C
# ref C
# correct deleted seq comfirmation above, same is good
# strins T
# var G
# strins A
# var G
# strins G
# var A
# strins C
# var C
# correct inserted seq comfirmation above, same is good
#
#
#  Variant#9 Variant:c.0021_0039inv##PP --- matched 9
# in rule verification 9 ----------------------c.0021_0039inv##PP
# 21
# 39
# PP
# var head offset 9---4
# offsetapplicablepair == 5
# 19
# GACAGGCTGTGGGGTTTCT
# AGAAACCCCACAGCCTGTC
# GACAGGCTGTGGGGTTTCT
# var A
# ref G
# var G
# ref A
# var A
# ref C
# var A
# ref A
# var A
# ref G
# var C
# ref G
# var C
# ref C
# var C
# ref T
# var C
# ref G
# var A
# ref T
# var C
# ref G
# var A
# ref G
# var G
# ref G
# var C
# ref G
# var C
# ref T
# var T
# ref T
# var G
# ref T
# var T
# ref C
# var C
# ref T
# strvarsegment which is inverted GACAGGCTGTGGGGTTTCT
# strvarsegment which is inverted back AGAAACCCCACAGCCTGTC
# strrefsegment GACAGGCTGTGGGGTTTCT
# inversion reverse complement comfirmation above, same [2 and 3] is good
# var next C
# ref next C
# var next A
# ref next A
# var next G
# ref next G
# var next A
# ref next A
# strnextvarsegment CAGA
# strnextrefsegment CAGA
# same segment comfirmation above, same is good
#
#
#  Variant#10 Variant:c.0021_0039con0061_0079##LP --- matched 10
# in rule verification 10 ----------------------c.0021_0039con0061_0079##LP
# 21
# 39
# 61
# 79
# LP
# var head offset 10---4
# offsetapplicablepair == 5
# FFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFF
# 19
# 19
# var G
# refcon T
# var A
# refcon C
# var C
# refcon A
# var A
# refcon G
# var G
# refcon G
# var G
# refcon A
# var C
# refcon G
# var T
# refcon G
# var G
# refcon C
# var T
# refcon C
# var G
# refcon T
# var G
# refcon T
# var G
# refcon C
# var G
# refcon A
# var T
# refcon C
# var T
# refcon C
# var T
# refcon C
# var C
# refcon T
# var T
# refcon C
# strvarsegment GACAGGCTGTGGGGTTTCT
# strrefsegment TCAGGAGGCCTTCACCCTC
# converted comfirmation above, i.e same [var, ref-con] is good
# var next C
# ref next C
# var next A
# ref next A
# var next G
# ref next G
# var next A
# ref next A
# strnextvarsegment CAGA
# strnextrefsegment CAGA
# same segment comfirmation above, same is good
#
#
#  Variant#11 Variant:c.0020G>T##BB --- matched 1
# in rule verification 1----------------------c.0020G>T##BB
# 20
# G
# T
# substitution confirmation 1
# BB
# var head offset 1---4
# offsetapplicablepair == 5
# G
# G
# substitution confirmation 2
#
#
#  Variant#12 Variant:c.0015_0018del##LB --- matched 2
# in rule verification 2----------------------c.0015_0018del##LB
# 15
# 18
# LB
# var head offset 2---4
# offsetapplicablepair == 5
# 4
# var A
# ref A
# var C
# ref C
# var G
# ref G
# var G
# ref G
# strvarsegment ACGG
# strrefsegment ACGG
# deletion comfirmation above, NOT same is good
# var next A
# ref next G
# var next C
# ref next G
# var next G
# ref next G
# var next G
# ref next A
# strnextvarsegment ACGG
# strnextrefsegment GGGA
# same segment confirmation above, same is good
#
#
#  Variant#13 Variant:c.0019_0022delGGGA##PP --- matched 3
# in rule verification 3----------------------c.0019_0022delGGGA##PP
# 19
# 22
# GGGA
# PP
# var head offset 3---4
# offsetapplicablepair == 5
# 4
# var G
# ref G
# var G
# ref G
# var G
# ref G
# var A
# ref A
# strvarsegment GGGA
# strrefsegment GGGA
# deletion comfirmation above, NOT same is good
# var next G
# ref next C
# var next G
# ref next A
# var next G
# ref next G
# var next A
# ref next G
# strnextvarsegment GGGA
# strnextrefsegment CAGG
# same segment comfirmation above, same is good
# strdel G
# ref G
# strdel G
# ref G
# strdel G
# ref G
# strdel A
# ref A
# right seq deleted comfirmation above, same is good
#
#
#  Variant#14 Variant:c.0019_0022dup##LP --- matched 4
# in rule verification 4----------------------c.0019_0022dup##LP
# 19
# 22
# LP
# var head offset 4---4
# offsetapplicablepair == 5
# 4
# var C
# ref G
# var A
# ref G
# var G
# ref G
# var G
# ref A
# strvarsegment CAGG
# strrefsegment GGGA
# duplication comfirmation above, same is good
# var next C
# ref next C
# var next T
# ref next A
# var next G
# ref next G
# var next T
# ref next G
# strnextvarsegment CTGT
# strnextrefsegment CAGG
# same segment comfirmation above, same is good
#
#
#  Variant#15 Variant:c.0023_0026dupCAGG##NN --- matched 5
# in rule verification 5----------------------c.0023_0026dupCAGG##NN
# 23
# 26
# CAGG
# NN
# var head offset 5---4
# offsetapplicablepair == 5
# 4
# var pos =  23
# var C
# ref pos =  23
# ref C
# var pos =  24
# var T
# ref pos =  24
# ref A
# var pos =  25
# var G
# ref pos =  25
# ref G
# var pos =  26
# var T
# ref pos =  26
# ref G
# strvarsegment CTGT
# strrefsegment CAGG
# duplication comfirmation above, same is good
# var next G
# ref next C
# var next G
# ref next T
# var next G
# ref next G
# var next G
# ref next T
# strnextvarsegment GGGG
# strnextrefsegment CTGT
# same segment comfirmation above, same is good
# strdup C
# ref C
# strdup A
# ref A
# strdup G
# ref G
# strdup G
# ref G
# correct duplicate seq comfirmation above, same is good
#
#
#  Variant#16 Variant:c.0022_0023insATATAT##BB --- matched 6
# in rule verification 6----------------------c.0022_0023insATATAT##BB
# 22
# 23
# ATATAT
# BB
# var head offset 6---4
# offsetapplicablepair == 5
# 2
# var C
# ref C
# var A
# ref A
# var G
# ref G
# var G
# ref G
# var C
# ref C
# var T
# ref T
# strvarsegment CAGGCT
# strrefsegment CAGGCT
# duplicated? why not inserted? comfirmation above, NOT same is good
# var next G
# ref next C
# var next T
# ref next A
# ...
# strrefsegment GGACGG
# duplicated? why not inserted? comfirmation above, NOT same is good
# var next G
# ref next G
# var next G
# ref next G
# var next G
# ref next A
# var next A
# ref next C
# strnextvarsegment GGGA
# strnextrefsegment GGAC
# same segment comfirmation above, same is good
# strins A
# var G
# strins T
# var G
# strins A
# var A
# strins T
# var C
# strins A
# var G
# strins T
# var G
# correct inserted seq comfirmation above, same is good
#
#
#  Variant#7 Variant:c.0009_0010delinsGGAA##LP --- matched 7
# in rule verification 7----------------------c.0009_0010delinsGGAA##LP
# 9
# 10
# GGAA
# LP
# var head offset 7--0
# offsetapplicablepair == 5
# 2
# var T
# ref T
# var C
# ref C
# strvarsegment TC
# strrefsegment TC
# deleted comfirmation above, not same is true
# var next G
# ref next C
# var next G
# ref next T
# var next A
# ref next G
# var next C
# ref next G
# strnextvarsegment GGAC
# strnextrefsegment CTGG
# same segment comfirmation above, same is good
# strdelins G
# var T
# strdelins G
# var C
# strdelins A
# var C
# strdelins A
# var T
# correct inserted seq comfirmation above, same is good
#
#
#  Variant#8 Variant:c.0009_0010delTCinsTAGC##LP --- matched 8
# in rule verification 8 ----------------------c.0009_0010delTCinsTAGC##LP
# 9
# 10
# T
# C
# i
# TC
# TAGC
# LP
# var head offset 8--0
# offsetapplicablepair == 5
# 2
# var T
# ref T
# var C
# ref C
# strvarsegment TC
# strrefsegment TC
# deleted comfirmation above. not same is good
# var next G
# ref next C
# var next G
# ref next T
# var next A
# ref next G
# var next C
# ref next G
# strnextvarsegment GGAC
# strnextrefsegment CTGG
# same segment comfirmation above, same is good
# strdel T
# ref T
# strdel C
# ref C
# correct deleted seq comfirmation above, same is good
# strins T
# var T
# strins A
# var C
# strins G
# var C
# strins C
# var T
# correct inserted seq comfirmation above, same is good
#
#
#  Variant#9 Variant:c.0021_0039inv##PP --- matched 9
# in rule verification 9 ----------------------c.0021_0039inv##PP
# 21
# 39
# PP
# var head offset 9--0
# offsetapplicablepair == 5
# 19
# GACAGGCTGTGGGGTTTCT
# AGAAACCCCACAGCCTGTC
# GACAGGCTGTGGGGTTTCT
# var A
# ref G
# var G
# ref A
# var A
# ref C
# var A
# ref A
# var A
# ref G
# var C
# ref G
# var C
# ref C
# var C
# ref T
# var C
# ref G
# var A
# ref T
# var C
# ref G
# var A
# ref G
# var G
# ref G
# var C
# ref G
# var C
# ref T
# var T
# ref T
# var G
# ref T
# var T
# ref C
# var C
# ref T
# strvarsegment which is inverted GACAGGCTGTGGGGTTTCT
# strvarsegment which is inverted back AGAAACCCCACAGCCTGTC
# strrefsegment GACAGGCTGTGGGGTTTCT
# inversion reverse complement comfirmation above, same [2 and 3] is good
# var next C
# ref next C
# var next G
# ref next A
# var next C
# ref next G
# var next T
# ref next A
# strnextvarsegment CGCT
# strnextrefsegment CAGA
# same segment comfirmation above, same is good
#
#
#  Variant#10 Variant:c.0021_0039con0061_0079##LP --- matched 10
# in rule verification 10 ----------------------c.0021_0039con0061_0079##LP
# 21
# 39
# 61
# 79
# LP
# var head offset 10--0
# offsetapplicablepair == 5
# FFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFF
# 19
# 19
# var G
# refcon T
# var A
# refcon C
# var C
# refcon A
# var A
# refcon G
# var G
# refcon G
# var G
# refcon A
# var C
# refcon G
# var T
# refcon G
# var G
# refcon C
# var T
# refcon C
# var G
# refcon T
# var G
# refcon T
# var G
# refcon C
# var G
# refcon A
# var T
# refcon C
# var T
# refcon C
# var T
# refcon C
# var C
# refcon T
# var T
# refcon C
# strvarsegment GACAGGCTGTGGGGTTTCT
# strrefsegment TCAGGAGGCCTTCACCCTC
# converted comfirmation above, i.e same [var, ref-con] is good
# var next C
# ref next C
# var next G
# ref next A
# var next C
# ref next G
# var next T
# ref next A
# strnextvarsegment CGCT
# strnextrefsegment CAGA
# same segment comfirmation above, same is good
#
#
#  Variant#11 Variant:c.0020G>T##BB --- matched 1
# in rule verification 1----------------------c.0020G>T##BB
# 20
# G
# T
# substitution confirmation 1
# BB
# var head offset 1--0
# offsetapplicablepair == 5
# G
# G
# substitution confirmation 2
#
#
#  Variant#12 Variant:c.0015_0018del##LB --- matched 2
# in rule verification 2----------------------c.0015_0018del##LB
# 15
# 18
# LB
# var head offset 2--0
# offsetapplicablepair == 5
# 4
# var A
# ref A
# var C
# ref C
# var G
# ref G
# var G
# ref G
# strvarsegment ACGG
# strrefsegment ACGG
# deletion comfirmation above, NOT same is good
# var next A
# ref next G
# var next C
# ref next G
# var next G
# ref next G
# var next G
# ref next A
# strnextvarsegment ACGG
# strnextrefsegment GGGA
# same segment confirmation above, same is good
#
#
#  Variant#13 Variant:c.0019_0022delGGGA##PP --- matched 3
# in rule verification 3----------------------c.0019_0022delGGGA##PP
# 19
# 22
# GGGA
# PP
# var head offset 3--0
# offsetapplicablepair == 5
# 4
# var G
# ref G
# var G
# ref G
# var G
# ref G
# var A
# ref A
# strvarsegment GGGA
# strrefsegment GGGA
# deletion comfirmation above, NOT same is good
# var next G
# ref next C
# var next G
# ref next A
# var next G
# ref next G
# var next A
# ref next G
# strnextvarsegment GGGA
# strnextrefsegment CAGG
# same segment comfirmation above, same is good
# strdel G
# ref G
# strdel G
# ref G
# strdel G
# ref G
# strdel A
# ref A
# right seq deleted comfirmation above, same is good
#
#
#  Variant#14 Variant:c.0019_0022dup##LP --- matched 4
# in rule verification 4----------------------c.0019_0022dup##LP
# 19
# 22
# LP
# var head offset 4--0
# offsetapplicablepair == 5
# 4
# var C
# ref G
# var A
# ref G
# var G
# ref G
# var G
# ref A
# strvarsegment CAGG
# strrefsegment GGGA
# duplication comfirmation above, same is good
# var next C
# ref next C
# var next T
# ref next A
# var next G
# ref next G
# var next T
# ref next G
# strnextvarsegment CTGT
# strnextrefsegment CAGG
# same segment comfirmation above, same is good
#
#
#  Variant#15 Variant:c.0023_0026dupCAGG##NN --- matched 5
# in rule verification 5----------------------c.0023_0026dupCAGG##NN
# 23
# 26
# CAGG
# NN
# var head offset 5--0
# offsetapplicablepair == 5
# 4
# var pos =  27
# var C
# ref pos =  23
# ref C
# var pos =  28
# var T
# ref pos =  24
# ref A
# var pos =  29
# var G
# ref pos =  25
# ref G
# var pos =  30
# var T
# ref pos =  26
# ref G
# strvarsegment CTGT
# strrefsegment CAGG
# duplication comfirmation above, same is good
# var next G
# ref next C
# var next G
# ref next T
# var next G
# ref next G
# var next G
# ref next T
# strnextvarsegment GGGG
# strnextrefsegment CTGT
# same segment comfirmation above, same is good
# strdup C
# ref C
# strdup A
# ref A
# strdup G
# ref G
# strdup G
# ref G
# correct duplicate seq comfirmation above, same is good
#
#
#  Variant#16 Variant:c.0022_0023insATATAT##BB --- matched 6
# in rule verification 6----------------------c.0022_0023insATATAT##BB
# 22
# 23
# ATATAT
# BB
# var head offset 6--0
# offsetapplicablepair == 5
# 2
# var C
# ref C
# var A
# ref A
# var G
# ref G
# var G
# ref G
# var C
# ref C
# var T
# ref T
# strvarsegment CAGGCT
# strrefsegment CAGGCT
# duplicated? why not inserted? comfirmation above, NOT same is good
# var next G
# ref next C
# var next T
# ref next A
# var next G
# ref next G
# var next G
# ref next G
# strnextvarsegment GTGG
# strnextrefsegment CAGG
# same segment comfirmation above, same is good
# strins A
# var C
# strins T
# var A
# strins A
# var G
# strins T
# var G
# strins A
# var C
# strins T
# var T
# correct inserted seq comfirmation above, same is good
#
#
#  Variant#17 Variant:c.0020_0021delinsCATG##LP --- matched 7
# in rule verification 7----------------------c.0020_0021delinsCATG##LP
# 20
# 21
# CATG
# LP
# var head offset 7--0
# offsetapplicablepair == 5
# 2
# var G
# ref G
# var G
# ref G
# strvarsegment GG
# strrefsegment GG
# deleted comfirmation above, not same is true
# var next A
# ref next A
# var next G
# ref next C
# var next G
# ref next A
# var next C
# ref next G
# strnextvarsegment AGGC
# strnextrefsegment ACAG
# same segment comfirmation above, same is good
# strdelins C
# var G
# strdelins A
# var G
# strdelins T
# var A
# strdelins G
# var C
# correct inserted seq comfirmation above, same is good
#
#
#  Variant#18 Variant:c.0019_0020delGGinsCAGT##LP --- matched 8
# in rule verification 8 ----------------------c.0019_0020delGGinsCAGT##LP
# 19
# 20
# G
# G
# i
# GG
# CAGT
# LP
# var head offset 8--0
# offsetapplicablepair == 5
# 2
# var G
# ref G
# var G
# ref G
# strvarsegment GG
# strrefsegment GG
# deleted comfirmation above. not same is good
# var next C
# ref next G
# var next A
# ref next A
# var next G
# ref next C
# var next G
# ref next A
# strnextvarsegment CAGG
# strnextrefsegment GACA
# same segment comfirmation above, same is good
# strdel G
# ref G
# strdel G
# ref G
# correct deleted seq comfirmation above, same is good
# strins C
# var G
# strins A
# var G
# strins G
# var G
# strins T
# var A
# correct inserted seq comfirmation above, same is good
#
#
#  Variant#19 Variant:c.0031_0049inv##PP --- matched 9
# in rule verification 9 ----------------------c.0031_0049inv##PP
# 31
# 49
# PP
# var head offset 9--0
# offsetapplicablepair == 5
# 19
# GGGGTTTCTCGCTCTGGGT
# ACCCAGAGCGAGAAACCCC
# GGGGTTTCTCAGATAACTG
# var A
# ref G
# var C
# ref G
# var C
# ref G
# var C
# ref G
# var A
# ref T
# var G
# ref T
# var A
# ref T
# var G
# ref C
# var C
# ref T
# var G
# ref C
# var A
# ref A
# var G
# ref G
# var A
# ref A
# var A
# ref T
# var A
# ref A
# var C
# ref A
# var C
# ref C
# var C
# ref T
# var C
# ref G
# strvarsegment which is inverted GGGGTTTCTCGCTCTGGGT
# strvarsegment which is inverted back ACCCAGAGCGAGAAACCCC
# strrefsegment GGGGTTTCTCAGATAACTG
# inversion reverse complement comfirmation above, same [2 and 3] is good
# var next A
# ref next G
# var next A
# ref next G
# var next A
# ref next C
# var next G
# ref next C
# strnextvarsegment AAAG
# strnextrefsegment GGCC
# same segment comfirmation above, same is good
#
#
#  Variant#20 Variant:c.0031_0049con0071_0089##LP --- matched 10
# in rule verification 10 ----------------------c.0031_0049con0071_0089##LP
# 31
# 49
# 71
# 89
# LP
# var head offset 10--0
# offsetapplicablepair == 5
# FFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFF
# 19
# 19
# var G
# refcon T
# var G
# refcon T
# var G
# refcon C
# var G
# refcon A
# var T
# refcon C
# var T
# refcon C
# var T
# refcon C
# var C
# refcon T
# var T
# refcon C
# var C
# refcon T
# var G
# refcon G
# var C
# refcon C
# var T
# refcon T
# var C
# refcon C
# var T
# refcon T
# var G
# refcon G
# var G
# refcon G
# var G
# refcon G
# var T
# refcon T
# strvarsegment GGGGTTTCTCGCTCTGGGT
# strrefsegment TTCACCCTCTGCTCTGGGT
# converted comfirmation above, i.e same [var, ref-con] is good
# var next A
# ref next G
# var next A
# ref next G
# var next A
# ref next C
# var next G
# ref next C
# strnextvarsegment AAAG
# strnextrefsegment GGCC
# same segment comfirmation above, same is good
#
#
#  Variant#21 Variant:c.0030T>A##BB --- matched 1
# in rule verification 1----------------------c.0030T>A##BB
# 30
# T
# A
# substitution confirmation 1
# BB
# var head offset 1--0
# offsetapplicablepair == 5
# T
# T
# substitution confirmation 2
#
#
#  Variant#22 Variant:c.0025_0028del##LB --- matched 2
# in rule verification 2----------------------c.0025_0028del##LB
# 25
# 28
# LB
# var head offset 2--0
# offsetapplicablepair == 5
# 4
# var G
# ref G
# var G
# ref G
# var C
# ref C
# var T
# ref T
# strvarsegment GGCT
# strrefsegment GGCT
# deletion comfirmation above, NOT same is good
# var next G
# ref next G
# var next G
# ref next T
# var next C
# ref next G
# var next T
# ref next G
# strnextvarsegment GGCT
# strnextrefsegment GTGG
# same segment confirmation above, same is good
#
#
#  Variant#23 Variant:c.0030_0033delTGGG##PP --- matched 3
# in rule verification 3----------------------c.0030_0033delTGGG##PP
# 30
# 33
# TGGG
# PP
# var head offset 3--0
# offsetapplicablepair == 5
# 4
# var T
# ref T
# var G
# ref G
# var G
# ref G
# var G
# ref G
# strvarsegment TGGG
# strrefsegment TGGG
# deletion comfirmation above, NOT same is good
# var next T
# ref next G
# var next G
# ref next T
# var next G
# ref next T
# var next G
# ref next T
# strnextvarsegment TGGG
# strnextrefsegment GTTT
# same segment comfirmation above, same is good
# strdel T
# ref T
# strdel G
# ref G
# strdel G
# ref G
# strdel G
# ref G
# right seq deleted comfirmation above, same is good
#
#
#  Variant#24 Variant:c.0029_0032dup##LP --- matched 4
# in rule verification 4----------------------c.0029_0032dup##LP
# 29
# 32
# LP
# var head offset 4--0
# offsetapplicablepair == 5
# 4
# var G
# ref G
# var G
# ref T
# var T
# ref G
# var T
# ref G
# strvarsegment GGTT
# strrefsegment GTGG
# duplication comfirmation above, same is good
# var next T
# ref next G
# var next C
# ref next G
# var next T
# ref next T
# var next C
# ref next T
# strnextvarsegment TCTC
# strnextrefsegment GGTT
# same segment comfirmation above, same is good
#
#
#  Variant#25 Variant:c.0040_0043dupCAGA##NN --- matched 5
# in rule verification 5----------------------c.0040_0043dupCAGA##NN
# 40
# 43
# CAGA
# NN
# var head offset 5--0
# offsetapplicablepair == 5
# 4
# var pos =  44
# var C
# ref pos =  40
# ref C
# var pos =  45
# var T
# ref pos =  41
# ref A
# var pos =  46
# var G
# ref pos =  42
# ref G
# var pos =  47
# var G
# ref pos =  43
# ref A
# strvarsegment CTGG
# strrefsegment CAGA
# duplication comfirmation above, same is good
# var next G
# ref next T
# var next T
# ref next A
# var next A
# ref next A
# var next A
# ref next C
# strnextvarsegment GTAA
# strnextrefsegment TAAC
# same segment comfirmation above, same is good
# strdup C
# ref C
# strdup A
# ref A
# strdup G
# ref G
# strdup A
# ref A
# correct duplicate seq comfirmation above, same is good
#
#
#  Variant#26 Variant:c.0032_0033insATATAT##BB --- matched 6
# in rule verification 6----------------------c.0032_0033insATATAT##BB
# 32
# 33
# ATATAT
# BB
# var head offset 6--0
# offsetapplicablepair == 5
# 2
# var G
# ref G
# var G
# ref G
# var T
# ref T
# var T
# ref T
# var T
# ref T
# var C
# ref C
# strvarsegment GGTTTC
# strrefsegment GGTTTC
# duplicated? why not inserted? comfirmation above, NOT same is good
# var next T
# ref next G
# var next C
# ref next G
# var next G
# ref next T
# var next C
# ref next T
# strnextvarsegment TCGC
# strnextrefsegment GGTT
# same segment comfirmation above, same is good
# strins A
# var G
# strins T
# var G
# strins A
# var T
# strins T
# var T
# strins A
# var T
# strins T
# var C
# correct inserted seq comfirmation above, same is good
#
#
#  Variant#27 Variant:c.0029_0030delinsGGAA##LP --- matched 7
# in rule verification 7----------------------c.0029_0030delinsGGAA##LP
# 29
# 30
# GGAA
# LP
# var head offset 7--0
# offsetapplicablepair == 5
# 2
# var G
# ref G
# var T
# ref T
# strvarsegment GT
# strrefsegment GT
# deleted comfirmation above, not same is true
# var next G
# ref next G
# var next G
# ref next G
# var next T
# ref next G
# var next T
# ref next G
# strnextvarsegment GGTT
# strnextrefsegment GGGG
# same segment comfirmation above, same is good
# strdelins G
# var G
# strdelins G
# var T
# strdelins A
# var G
# strdelins A
# var G
# correct inserted seq comfirmation above, same is good
#
#
#  Variant#28 Variant:c.0029_0030delGTinsCCTT##LP --- matched 8
# in rule verification 8 ----------------------c.0029_0030delGTinsCCTT##LP
# 29
# 30
# G
# T
# i
# GT
# CCTT
# LP
# var head offset 8--0
# offsetapplicablepair == 5
# 2
# var G
# ref G
# var T
# ref T
# strvarsegment GT
# strrefsegment GT
# deleted comfirmation above. not same is good
# var next G
# ref next G
# var next G
# ref next G
# var next T
# ref next G
# var next T
# ref next G
# strnextvarsegment GGTT
# strnextrefsegment GGGG
# same segment comfirmation above, same is good
# strdel G
# ref G
# strdel T
# ref T
# correct deleted seq comfirmation above, same is good
# strins C
# var G
# strins C
# var T
# strins T
# var G
# strins T
# var G
# correct inserted seq comfirmation above, same is good
#
#
#  Variant#29 Variant:c.0041_0059inv##PP --- matched 9
# in rule verification 9 ----------------------c.0041_0059inv##PP
# 41
# 59
# PP
# var head offset 9--0
# offsetapplicablepair == 5
# 19
# GCTCTGGGTAAAGTTCATT
# AATGAACTTTACCCAGAGC
# AGATAACTGGGCCCCTGCG
# var A
# ref A
# var A
# ref G
# var T
# ref A
# var G
# ref T
# var A
# ref A
# var A
# ref A
# var C
# ref C
# var T
# ref T
# var T
# ref G
# var T
# ref G
# var A
# ref G
# var C
# ref C
# var C
# ref C
# var C
# ref C
# var A
# ref C
# var G
# ref T
# var A
# ref G
# var G
# ref C
# var C
# ref G
# strvarsegment which is inverted GCTCTGGGTAAAGTTCATT
# strvarsegment which is inverted back AATGAACTTTACCCAGAGC
# strrefsegment AGATAACTGGGCCCCTGCG
# inversion reverse complement comfirmation above, same [2 and 3] is good
# var next C
# ref next C
# var next T
# ref next T
# var next C
# ref next C
# var next A
# ref next A
# strnextvarsegment CTCA
# strnextrefsegment CTCA
# same segment comfirmation above, same is good
#
#
#  Variant#30 Variant:c.0041_0059con0081_0099##LP --- matched 10
# in rule verification 10 ----------------------c.0041_0059con0081_0099##LP
# 41
# 59
# 81
# 99
# LP
# var head offset 10--0
# offsetapplicablepair == 5
# FFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFF
# 19
# 19
# var G
# refcon G
# var C
# refcon C
# var T
# refcon T
# var C
# refcon C
# var T
# refcon T
# var G
# refcon G
# var G
# refcon G
# var G
# refcon G
# var T
# refcon T
# var A
# refcon A
# var A
# refcon A
# var A
# refcon A
# var G
# refcon G
# var T
# refcon T
# var T
# refcon T
# var C
# refcon C
# var A
# refcon A
# var T
# refcon T
# var T
# refcon T
# strvarsegment GCTCTGGGTAAAGTTCATT
# strrefsegment GCTCTGGGTAAAGTTCATT
# converted comfirmation above, i.e same [var, ref-con] is good
# var next C
# ref next C
# var next T
# ref next T
# var next C
# ref next C
# var next A
# ref next A
# strnextvarsegment CTCA
# strnextrefsegment CTCA
# same segment comfirmation above, same is good
# c.0041_0059con0081_0099##LP      PRESENT                                         ******************

# %%
for i in range(len(reportlines)):
        print(reportlines[i])
# Out:
#                            KAIGENIX CLINICAL MANAGEMENT - GENOMICS DEPT.
#                             Genetic Variations Report (for BRCA1 gene)
#
# Details:
# --------------------------------------------------------------------------------------------------------------------------
# --------------------------------------------------------------------------------------------------------------------------
# For file:   P001-BRCA1-VAR01.fasta
# GCTGAGACTTTCTGGACGGG|GGACAGGCTGTGGGGTTTCT|CAGATAACTGGGCCCCTGCG|CTCAGGAGGCCTTCACCCTC|TGCTCTGGGTAAAGTTCATT
# GCTGAGACTTCCTGGACGGG|GGACAGGCTGTGGGGTTTCT|CAGATAACTGGGCCCCTGCG|CTCAGGAGGCCTTCACCCTC|TGCTCTGGGTAAAGTTCATT
# --------------------------------------------------------------------------------------------------------------------------
# VARIANT |->| c.0010C>T##BB                           |->| PRESENT  !!!!!!!!!!!!!!       |->| Diagnosis: BENIGN
# VARIANT |->| c.0005_0008del##LB                      |->| Absent                        |->| ---
# VARIANT |->| c.0009_0012delTCCT##PP                  |->| Absent                        |->| ---
# VARIANT |->| c.0009_0012dup##LP                      |->| Absent                        |->| ---
# VARIANT |->| c.0014_0017dupGACG##NN                  |->| Absent                        |->| ---
# VARIANT |->| c.0012_0013insATATAT##BB                |->| Absent                        |->| ---
# VARIANT |->| c.0009_0010delinsGGAA##LP               |->| Absent                        |->| ---
# VARIANT |->| c.0009_0010delTCinsTAGC##LP             |->| Absent                        |->| ---
# VARIANT |->| c.0021_0039inv##PP                      |->| Absent                        |->| ---
# VARIANT |->| c.0021_0039con0061_0079##LP             |->| Absent                        |->| ---
# VARIANT |->| c.0020G>T##BB                           |->| Absent                        |->| ---
# VARIANT |->| c.0015_0018del##LB                      |->| Absent                        |->| ---
# VARIANT |->| c.0019_0022delGGGA##PP                  |->| Absent                        |->| ---
# VARIANT |->| c.0019_0022dup##LP                      |->| Absent                        |->| ---
# VARIANT |->| c.0023_0026dupCAGG##NN                  |->| Absent                        |->| ---
# VARIANT |->| c.0022_0023insATATAT##BB                |->| Absent                        |->| ---
# VARIANT |->| c.0020_0021delinsCATG##LP               |->| Absent                        |->| ---
# VARIANT |->| c.0019_0020delGGinsCAGT##LP             |->| Absent                        |->| ---
# VARIANT |->| c.0031_0049inv##PP                      |->| Absent                        |->| ---
# VARIANT |->| c.0031_0049con0071_0089##LP             |->| Absent                        |->| ---
# VARIANT |->| c.0030T>A##BB                           |->| Absent                        |->| ---
# VARIANT |->| c.0025_0028del##LB                      |->| Absent                        |->| ---
# VARIANT |->| c.0030_0033delTGGG##PP                  |->| Absent                        |->| ---
# VARIANT |->| c.0029_0032dup##LP                      |->| Absent                        |->| ---
# VARIANT |->| c.0040_0043dupCAGA##NN                  |->| Absent                        |->| ---
# VARIANT |->| c.0032_0033insATATAT##BB                |->| Absent                        |->| ---
# VARIANT |->| c.0029_0030delinsGGAA##LP               |->| Absent                        |->| ---
# VARIANT |->| c.0029_0030delGTinsCCTT##LP             |->| Absent                        |->| ---
# VARIANT |->| c.0041_0059inv##PP                      |->| Absent                        |->| ---
# VARIANT |->| c.0041_0059con0081_0099##LP             |->| Absent                        |->| ---
# --------------------------------------------------------------------------------------------------------------------------
# For file:   P001-BRCA1-VAR02.fasta
# GCTGATCCTGGACGGGGGAC|AGGCTGTGGGGTTTCTCAGA|TAACTGGGCCCCTGCGCTCA|GGAGGCCTTCACCCTCTGCT|CTGGGTAAAGTTCATTGGAA
# GCTGAGACTTCCTGGACGGG|GGACAGGCTGTGGGGTTTCT|CAGATAACTGGGCCCCTGCG|CTCAGGAGGCCTTCACCCTC|TGCTCTGGGTAAAGTTCATT
# --------------------------------------------------------------------------------------------------------------------------
# VARIANT |->| c.0010C>T##BB                           |->| Absent                        |->| ---
# VARIANT |->| c.0005_0008del##LB                      |->| PRESENT  !!!!!!!!!!!!!!       |->| Diagnosis: LIKELY BENIGN
# VARIANT |->| c.0009_0012delTCCT##PP                  |->| Absent                        |->| ---
# VARIANT |->| c.0009_0012dup##LP                      |->| Absent                        |->| ---
# VARIANT |->| c.0014_0017dupGACG##NN                  |->| Absent                        |->| ---
# VARIANT |->| c.0012_0013insATATAT##BB                |->| Absent                        |->| ---
# VARIANT |->| c.0009_0010delinsGGAA##LP               |->| Absent                        |->| ---
# VARIANT |->| c.0009_0010delTCinsTAGC##LP             |->| Absent                        |->| ---
# VARIANT |->| c.0021_0039inv##PP                      |->| Absent                        |->| ---
# VARIANT |->| c.0021_0039con0061_0079##LP             |->| Absent                        |->| ---
# VARIANT |->| c.0020G>T##BB                           |->| Absent                        |->| ---
# VARIANT |->| c.0015_0018del##LB                      |->| Absent                        |->| ---
# VARIANT |->| c.0019_0022delGGGA##PP                  |->| Absent                        |->| ---
# VARIANT |->| c.0019_0022dup##LP                      |->| Absent                        |->| ---
# VARIANT |->| c.0023_0026dupCAGG##NN                  |->| Absent                        |->| ---
# VARIANT |->| c.0022_0023insATATAT##BB                |->| Absent                        |->| ---
# VARIANT |->| c.0020_0021delinsCATG##LP               |->| Absent                        |->| ---
# VARIANT |->| c.0019_0020delGGinsCAGT##LP             |->| Absent                        |->| ---
# VARIANT |->| c.0031_0049inv##PP                      |->| Absent                        |->| ---
# VARIANT |->| c.0031_0049con0071_0089##LP             |->| Absent                        |->| ---
# VARIANT |->| c.0030T>A##BB                           |->| Absent                        |->| ---
# VARIANT |->| c.0025_0028del##LB                      |->| Absent                        |->| ---
# VARIANT |->| c.0030_0033delTGGG##PP                  |->| Absent                        |->| ---
# VARIANT |->| c.0029_0032dup##LP                      |->| Absent                        |->| ---
# VARIANT |->| c.0040_0043dupCAGA##NN                  |->| Absent                        |->| ---
# VARIANT |->| c.0032_0033insATATAT##BB                |->| Absent                        |->| ---
# VARIANT |->| c.0029_0030delinsGGAA##LP               |->| Absent                        |->| ---
# VARIANT |->| c.0029_0030delGTinsCCTT##LP             |->| Absent                        |->| ---
# VARIANT |->| c.0041_0059inv##PP                      |->| Absent                        |->| ---
# VARIANT |->| c.0041_0059con0081_0099##LP             |->| Absent                        |->| ---
# --------------------------------------------------------------------------------------------------------------------------
# For file:   P001-BRCA1-VAR03.fasta
# GCTGAGACTGGACGGGGGAC|AGGCTGTGGGGTTTCTCAGA|TAACTGGGCCCCTGCGCTCA|GGAGGCCTTCACCCTCTGCT|CTGGGTAAAGTTCATTGGAA
# GCTGAGACTTCCTGGACGGG|GGACAGGCTGTGGGGTTTCT|CAGATAACTGGGCCCCTGCG|CTCAGGAGGCCTTCACCCTC|TGCTCTGGGTAAAGTTCATT
# --------------------------------------------------------------------------------------------------------------------------
# VARIANT |->| c.0010C>T##BB                           |->| Absent                        |->| ---
# VARIANT |->| c.0005_0008del##LB                      |->| Absent                        |->| ---
# VARIANT |->| c.0009_0012delTCCT##PP                  |->| PRESENT  !!!!!!!!!!!!!!       |->| Diagnosis: PATHOLOGICAL
# VARIANT |->| c.0009_0012dup##LP                      |->| Absent                        |->| ---
# VARIANT |->| c.0014_0017dupGACG##NN                  |->| Absent                        |->| ---
# VARIANT |->| c.0012_0013insATATAT##BB                |->| Absent                        |->| ---
# VARIANT |->| c.0009_0010delinsGGAA##LP               |->| Absent                        |->| ---
# VARIANT |->| c.0009_0010delTCinsTAGC##LP             |->| Absent                        |->| ---
# VARIANT |->| c.0021_0039inv##PP                      |->| Absent                        |->| ---
# VARIANT |->| c.0021_0039con0061_0079##LP             |->| Absent                        |->| ---
# VARIANT |->| c.0020G>T##BB                           |->| Absent                        |->| ---
# VARIANT |->| c.0015_0018del##LB                      |->| Absent                        |->| ---
# VARIANT |->| c.0019_0022delGGGA##PP                  |->| Absent                        |->| ---
# VARIANT |->| c.0019_0022dup##LP                      |->| Absent                        |->| ---
# VARIANT |->| c.0023_0026dupCAGG##NN                  |->| Absent                        |->| ---
# VARIANT |->| c.0022_0023insATATAT##BB                |->| Absent                        |->| ---
# VARIANT |->| c.0020_0021delinsCATG##LP               |->| Absent                        |->| ---
# VARIANT |->| c.0019_0020delGGinsCAGT##LP             |->| Absent                        |->| ---
# VARIANT |->| c.0031_0049inv##PP                      |->| Absent                        |->| ---
# VARIANT |->| c.0031_0049con0071_0089##LP             |->| Absent                        |->| ---
# VARIANT |->| c.0030T>A##BB                           |->| Absent                        |->| ---
# VARIANT |->| c.0025_0028del##LB                      |->| Absent                        |->| ---
# VARIANT |->| c.0030_0033delTGGG##PP                  |->| Absent                        |->| ---
# VARIANT |->| c.0029_0032dup##LP                      |->| Absent                        |->| ---
# VARIANT |->| c.0040_0043dupCAGA##NN                  |->| Absent                        |->| ---
# VARIANT |->| c.0032_0033insATATAT##BB                |->| Absent                        |->| ---
# VARIANT |->| c.0029_0030delinsGGAA##LP               |->| Absent                        |->| ---
# VARIANT |->| c.0029_0030delGTinsCCTT##LP             |->| Absent                        |->| ---
# VARIANT |->| c.0041_0059inv##PP                      |->| Absent                        |->| ---
# VARIANT |->| c.0041_0059con0081_0099##LP             |->| Absent                        |->| ---
# --------------------------------------------------------------------------------------------------------------------------
# For file:   P001-BRCA1-VAR04.fasta
# GCTGAGACTTCCTTCCTGGA|CGGGGGACAGGCTGTGGGGT|TTCTCAGATAACTGGGCCCC|TGCGCTCAGGAGGCCTTCAC|CCTCTGCTCTGGGTAAAGTT
# GCTGAGACTTCCTGGACGGG|GGACAGGCTGTGGGGTTTCT|CAGATAACTGGGCCCCTGCG|CTCAGGAGGCCTTCACCCTC|TGCTCTGGGTAAAGTTCATT
# --------------------------------------------------------------------------------------------------------------------------
# VARIANT |->| c.0010C>T##BB                           |->| Absent                        |->| ---
# VARIANT |->| c.0005_0008del##LB                      |->| Absent                        |->| ---
# VARIANT |->| c.0009_0012delTCCT##PP                  |->| Absent                        |->| ---
# VARIANT |->| c.0009_0012dup##LP                      |->| PRESENT  !!!!!!!!!!!!!!       |->| Diagnosis: LIKELY PATHOLOGICAL
# VARIANT |->| c.0014_0017dupGACG##NN                  |->| Absent                        |->| ---
# VARIANT |->| c.0012_0013insATATAT##BB                |->| Absent                        |->| ---
# VARIANT |->| c.0009_0010delinsGGAA##LP               |->| Absent                        |->| ---
# VARIANT |->| c.0009_0010delTCinsTAGC##LP             |->| Absent                        |->| ---
# VARIANT |->| c.0021_0039inv##PP                      |->| Absent                        |->| ---
# VARIANT |->| c.0021_0039con0061_0079##LP             |->| Absent                        |->| ---
# VARIANT |->| c.0020G>T##BB                           |->| Absent                        |->| ---
# VARIANT |->| c.0015_0018del##LB                      |->| Absent                        |->| ---
# VARIANT |->| c.0019_0022delGGGA##PP                  |->| Absent                        |->| ---
# VARIANT |->| c.0019_0022dup##LP                      |->| Absent                        |->| ---
# VARIANT |->| c.0023_0026dupCAGG##NN                  |->| Absent                        |->| ---
# VARIANT |->| c.0022_0023insATATAT##BB                |->| Absent                        |->| ---
# VARIANT |->| c.0020_0021delinsCATG##LP               |->| Absent                        |->| ---
# VARIANT |->| c.0019_0020delGGinsCAGT##LP             |->| Absent                        |->| ---
# VARIANT |->| c.0031_0049inv##PP                      |->| Absent                        |->| ---
# VARIANT |->| c.0031_0049con0071_0089##LP             |->| Absent                        |->| ---
# VARIANT |->| c.0030T>A##BB                           |->| Absent                        |->| ---
# VARIANT |->| c.0025_0028del##LB                      |->| Absent                        |->| ---
# VARIANT |->| c.0030_0033delTGGG##PP                  |->| Absent                        |->| ---
# VARIANT |->| c.0029_0032dup##LP                      |->| Absent                        |->| ---
# VARIANT |->| c.0040_0043dupCAGA##NN                  |->| Absent                        |->| ---
# VARIANT |->| c.0032_0033insATATAT##BB                |->| Absent                        |->| ---
# VARIANT |->| c.0029_0030delinsGGAA##LP               |->| Absent                        |->| ---
# VARIANT |->| c.0029_0030delGTinsCCTT##LP             |->| Absent                        |->| ---
# VARIANT |->| c.0041_0059inv##PP                      |->| Absent                        |->| ---
# VARIANT |->| c.0041_0059con0081_0099##LP             |->| Absent                        |->| ---
# --------------------------------------------------------------------------------------------------------------------------
# For file:   P001-BRCA1-VAR05.fasta
# GCTGAGACTTCCTGGACGGA|CGGGGGACAGGCTGTGGGGT|TTCTCAGATAACTGGGCCCC|TGCGCTCAGGAGGCCTTCAC|CCTCTGCTCTGGGTAAAGTT
# GCTGAGACTTCCTGGACGGG|GGACAGGCTGTGGGGTTTCT|CAGATAACTGGGCCCCTGCG|CTCAGGAGGCCTTCACCCTC|TGCTCTGGGTAAAGTTCATT
# --------------------------------------------------------------------------------------------------------------------------
# VARIANT |->| c.0010C>T##BB                           |->| Absent                        |->| ---
# VARIANT |->| c.0005_0008del##LB                      |->| Absent                        |->| ---
# VARIANT |->| c.0009_0012delTCCT##PP                  |->| Absent                        |->| ---
# VARIANT |->| c.0009_0012dup##LP                      |->| Absent                        |->| ---
# VARIANT |->| c.0014_0017dupGACG##NN                  |->| PRESENT  !!!!!!!!!!!!!!       |->| Diagnosis: NOT KNOWN
# VARIANT |->| c.0012_0013insATATAT##BB                |->| Absent                        |->| ---
# VARIANT |->| c.0009_0010delinsGGAA##LP               |->| Absent                        |->| ---
# VARIANT |->| c.0009_0010delTCinsTAGC##LP             |->| Absent                        |->| ---
# VARIANT |->| c.0021_0039inv##PP                      |->| Absent                        |->| ---
# VARIANT |->| c.0021_0039con0061_0079##LP             |->| Absent                        |->| ---
# VARIANT |->| c.0020G>T##BB                           |->| Absent                        |->| ---
# VARIANT |->| c.0015_0018del##LB                      |->| Absent                        |->| ---
# VARIANT |->| c.0019_0022delGGGA##PP                  |->| Absent                        |->| ---
# VARIANT |->| c.0019_0022dup##LP                      |->| Absent                        |->| ---
# VARIANT |->| c.0023_0026dupCAGG##NN                  |->| Absent                        |->| ---
# VARIANT |->| c.0022_0023insATATAT##BB                |->| Absent                        |->| ---
# VARIANT |->| c.0020_0021delinsCATG##LP               |->| Absent                        |->| ---
# VARIANT |->| c.0019_0020delGGinsCAGT##LP             |->| Absent                        |->| ---
# VARIANT |->| c.0031_0049inv##PP                      |->| Absent                        |->| ---
# VARIANT |->| c.0031_0049con0071_0089##LP             |->| Absent                        |->| ---
# VARIANT |->| c.0030T>A##BB                           |->| Absent                        |->| ---
# VARIANT |->| c.0025_0028del##LB                      |->| Absent                        |->| ---
# VARIANT |->| c.0030_0033delTGGG##PP                  |->| Absent                        |->| ---
# VARIANT |->| c.0029_0032dup##LP                      |->| Absent                        |->| ---
# VARIANT |->| c.0040_0043dupCAGA##NN                  |->| Absent                        |->| ---
# VARIANT |->| c.0032_0033insATATAT##BB                |->| Absent                        |->| ---
# VARIANT |->| c.0029_0030delinsGGAA##LP               |->| Absent                        |->| ---
# VARIANT |->| c.0029_0030delGTinsCCTT##LP             |->| Absent                        |->| ---
# VARIANT |->| c.0041_0059inv##PP                      |->| Absent                        |->| ---
# VARIANT |->| c.0041_0059con0081_0099##LP             |->| Absent                        |->| ---
# --------------------------------------------------------------------------------------------------------------------------
# For file:   P001-BRCA1-VAR06.fasta
# GCTGAGACTTCCTATATATG|GACGGGGGACAGGCTGTGGG|GTTTCTCAGATAACTGGGCC|CCTGCGCTCAGGAGGCCTTC|ACCCTCTGCTCTGGGTAAAG
# GCTGAGACTTCCTGGACGGG|GGACAGGCTGTGGGGTTTCT|CAGATAACTGGGCCCCTGCG|CTCAGGAGGCCTTCACCCTC|TGCTCTGGGTAAAGTTCATT
# --------------------------------------------------------------------------------------------------------------------------
# VARIANT |->| c.0010C>T##BB                           |->| Absent                        |->| ---
# VARIANT |->| c.0005_0008del##LB                      |->| Absent                        |->| ---
# VARIANT |->| c.0009_0012delTCCT##PP                  |->| Absent                        |->| ---
# VARIANT |->| c.0009_0012dup##LP                      |->| Absent                        |->| ---
# VARIANT |->| c.0014_0017dupGACG##NN                  |->| Absent                        |->| ---
# VARIANT |->| c.0012_0013insATATAT##BB                |->| PRESENT  !!!!!!!!!!!!!!       |->| Diagnosis: BENIGN
# VARIANT |->| c.0009_0010delinsGGAA##LP               |->| Absent                        |->| ---
# VARIANT |->| c.0009_0010delTCinsTAGC##LP             |->| Absent                        |->| ---
# VARIANT |->| c.0021_0039inv##PP                      |->| Absent                        |->| ---
# VARIANT |->| c.0021_0039con0061_0079##LP             |->| Absent                        |->| ---
# VARIANT |->| c.0020G>T##BB                           |->| Absent                        |->| ---
# VARIANT |->| c.0015_0018del##LB                      |->| Absent                        |->| ---
# VARIANT |->| c.0019_0022delGGGA##PP                  |->| Absent                        |->| ---
# VARIANT |->| c.0019_0022dup##LP                      |->| Absent                        |->| ---
# VARIANT |->| c.0023_0026dupCAGG##NN                  |->| Absent                        |->| ---
# VARIANT |->| c.0022_0023insATATAT##BB                |->| Absent                        |->| ---
# VARIANT |->| c.0020_0021delinsCATG##LP               |->| Absent                        |->| ---
# VARIANT |->| c.0019_0020delGGinsCAGT##LP             |->| Absent                        |->| ---
# VARIANT |->| c.0031_0049inv##PP                      |->| Absent                        |->| ---
# VARIANT |->| c.0031_0049con0071_0089##LP             |->| Absent                        |->| ---
# VARIANT |->| c.0030T>A##BB                           |->| Absent                        |->| ---
# VARIANT |->| c.0025_0028del##LB                      |->| Absent                        |->| ---
# VARIANT |->| c.0030_0033delTGGG##PP                  |->| Absent                        |->| ---
# VARIANT |->| c.0029_0032dup##LP                      |->| Absent                        |->| ---
# VARIANT |->| c.0040_0043dupCAGA##NN                  |->| Absent                        |->| ---
# VARIANT |->| c.0032_0033insATATAT##BB                |->| Absent                        |->| ---
# VARIANT |->| c.0029_0030delinsGGAA##LP               |->| Absent                        |->| ---
# VARIANT |->| c.0029_0030delGTinsCCTT##LP             |->| Absent                        |->| ---
# VARIANT |->| c.0041_0059inv##PP                      |->| Absent                        |->| ---
# VARIANT |->| c.0041_0059con0081_0099##LP             |->| Absent                        |->| ---
# --------------------------------------------------------------------------------------------------------------------------
# For file:   P001-BRCA1-VAR07.fasta
# GCTGAGACTGGAACTGGACG|GGGGACAGGCTGTGGGGTTT|CTCAGATAACTGGGCCCCTG|CGCTCAGGAGGCCTTCACCC|TCTGCTCTGGGTAAAGTTCA
# GCTGAGACTTCCTGGACGGG|GGACAGGCTGTGGGGTTTCT|CAGATAACTGGGCCCCTGCG|CTCAGGAGGCCTTCACCCTC|TGCTCTGGGTAAAGTTCATT
# --------------------------------------------------------------------------------------------------------------------------
# VARIANT |->| c.0010C>T##BB                           |->| Absent                        |->| ---
# VARIANT |->| c.0005_0008del##LB                      |->| Absent                        |->| ---
# VARIANT |->| c.0009_0012delTCCT##PP                  |->| Absent                        |->| ---
# VARIANT |->| c.0009_0012dup##LP                      |->| Absent                        |->| ---
# VARIANT |->| c.0014_0017dupGACG##NN                  |->| Absent                        |->| ---
# VARIANT |->| c.0012_0013insATATAT##BB                |->| Absent                        |->| ---
# VARIANT |->| c.0009_0010delinsGGAA##LP               |->| PRESENT  !!!!!!!!!!!!!!       |->| Diagnosis: LIKELY PATHOLOGICAL
# VARIANT |->| c.0009_0010delTCinsTAGC##LP             |->| Absent                        |->| ---
# VARIANT |->| c.0021_0039inv##PP                      |->| Absent                        |->| ---
# VARIANT |->| c.0021_0039con0061_0079##LP             |->| Absent                        |->| ---
# VARIANT |->| c.0020G>T##BB                           |->| Absent                        |->| ---
# VARIANT |->| c.0015_0018del##LB                      |->| Absent                        |->| ---
# VARIANT |->| c.0019_0022delGGGA##PP                  |->| Absent                        |->| ---
# VARIANT |->| c.0019_0022dup##LP                      |->| Absent                        |->| ---
# VARIANT |->| c.0023_0026dupCAGG##NN                  |->| Absent                        |->| ---
# VARIANT |->| c.0022_0023insATATAT##BB                |->| Absent                        |->| ---
# VARIANT |->| c.0020_0021delinsCATG##LP               |->| Absent                        |->| ---
# VARIANT |->| c.0019_0020delGGinsCAGT##LP             |->| Absent                        |->| ---
# VARIANT |->| c.0031_0049inv##PP                      |->| Absent                        |->| ---
# VARIANT |->| c.0031_0049con0071_0089##LP             |->| Absent                        |->| ---
# VARIANT |->| c.0030T>A##BB                           |->| Absent                        |->| ---
# VARIANT |->| c.0025_0028del##LB                      |->| Absent                        |->| ---
# VARIANT |->| c.0030_0033delTGGG##PP                  |->| Absent                        |->| ---
# VARIANT |->| c.0029_0032dup##LP                      |->| Absent                        |->| ---
# VARIANT |->| c.0040_0043dupCAGA##NN                  |->| Absent                        |->| ---
# VARIANT |->| c.0032_0033insATATAT##BB                |->| Absent                        |->| ---
# VARIANT |->| c.0029_0030delinsGGAA##LP               |->| Absent                        |->| ---
# VARIANT |->| c.0029_0030delGTinsCCTT##LP             |->| Absent                        |->| ---
# VARIANT |->| c.0041_0059inv##PP                      |->| Absent                        |->| ---
# VARIANT |->| c.0041_0059con0081_0099##LP             |->| Absent                        |->| ---
# --------------------------------------------------------------------------------------------------------------------------
# For file:   P001-BRCA1-VAR08.fasta
# GCTGAGACTTAGCCTGGACG|GGGGACAGGCTGTGGGGTTT|CTCAGATAACTGGGCCCCTG|CGCTCAGGAGGCCTTCACCC|TCTGCTCTGGGTAAAGTTCA
# GCTGAGACTTCCTGGACGGG|GGACAGGCTGTGGGGTTTCT|CAGATAACTGGGCCCCTGCG|CTCAGGAGGCCTTCACCCTC|TGCTCTGGGTAAAGTTCATT
# --------------------------------------------------------------------------------------------------------------------------
# VARIANT |->| c.0010C>T##BB                           |->| Absent                        |->| ---
# VARIANT |->| c.0005_0008del##LB                      |->| Absent                        |->| ---
# VARIANT |->| c.0009_0012delTCCT##PP                  |->| Absent                        |->| ---
# VARIANT |->| c.0009_0012dup##LP                      |->| Absent                        |->| ---
# VARIANT |->| c.0014_0017dupGACG##NN                  |->| Absent                        |->| ---
# VARIANT |->| c.0012_0013insATATAT##BB                |->| Absent                        |->| ---
# VARIANT |->| c.0009_0010delinsGGAA##LP               |->| Absent                        |->| ---
# VARIANT |->| c.0009_0010delTCinsTAGC##LP             |->| PRESENT  !!!!!!!!!!!!!!       |->| Diagnosis: LIKELY PATHOLOGICAL
# VARIANT |->| c.0021_0039inv##PP                      |->| Absent                        |->| ---
# VARIANT |->| c.0021_0039con0061_0079##LP             |->| Absent                        |->| ---
# VARIANT |->| c.0020G>T##BB                           |->| Absent                        |->| ---
# VARIANT |->| c.0015_0018del##LB                      |->| Absent                        |->| ---
# VARIANT |->| c.0019_0022delGGGA##PP                  |->| Absent                        |->| ---
# VARIANT |->| c.0019_0022dup##LP                      |->| Absent                        |->| ---
# VARIANT |->| c.0023_0026dupCAGG##NN                  |->| Absent                        |->| ---
# VARIANT |->| c.0022_0023insATATAT##BB                |->| Absent                        |->| ---
# VARIANT |->| c.0020_0021delinsCATG##LP               |->| Absent                        |->| ---
# VARIANT |->| c.0019_0020delGGinsCAGT##LP             |->| Absent                        |->| ---
# VARIANT |->| c.0031_0049inv##PP                      |->| Absent                        |->| ---
# VARIANT |->| c.0031_0049con0071_0089##LP             |->| Absent                        |->| ---
# VARIANT |->| c.0030T>A##BB                           |->| Absent                        |->| ---
# VARIANT |->| c.0025_0028del##LB                      |->| Absent                        |->| ---
# VARIANT |->| c.0030_0033delTGGG##PP                  |->| Absent                        |->| ---
# VARIANT |->| c.0029_0032dup##LP                      |->| Absent                        |->| ---
# VARIANT |->| c.0040_0043dupCAGA##NN                  |->| Absent                        |->| ---
# VARIANT |->| c.0032_0033insATATAT##BB                |->| Absent                        |->| ---
# VARIANT |->| c.0029_0030delinsGGAA##LP               |->| Absent                        |->| ---
# VARIANT |->| c.0029_0030delGTinsCCTT##LP             |->| Absent                        |->| ---
# VARIANT |->| c.0041_0059inv##PP                      |->| Absent                        |->| ---
# VARIANT |->| c.0041_0059con0081_0099##LP             |->| Absent                        |->| ---
# --------------------------------------------------------------------------------------------------------------------------
# For file:   P001-BRCA1-VAR09.fasta
# GCTGAGACTTCCTGGACGGG|GAGAAACCCCACAGCCTGTC|CAGATAACTGGGCCCCTGCG|CTCAGGAGGCCTTCACCCTC|TGCTCTGGGTAAAGTTCATT
# GCTGAGACTTCCTGGACGGG|GGACAGGCTGTGGGGTTTCT|CAGATAACTGGGCCCCTGCG|CTCAGGAGGCCTTCACCCTC|TGCTCTGGGTAAAGTTCATT
# --------------------------------------------------------------------------------------------------------------------------
# VARIANT |->| c.0010C>T##BB                           |->| Absent                        |->| ---
# VARIANT |->| c.0005_0008del##LB                      |->| Absent                        |->| ---
# VARIANT |->| c.0009_0012delTCCT##PP                  |->| Absent                        |->| ---
# VARIANT |->| c.0009_0012dup##LP                      |->| Absent                        |->| ---
# VARIANT |->| c.0014_0017dupGACG##NN                  |->| Absent                        |->| ---
# VARIANT |->| c.0012_0013insATATAT##BB                |->| Absent                        |->| ---
# VARIANT |->| c.0009_0010delinsGGAA##LP               |->| Absent                        |->| ---
# VARIANT |->| c.0009_0010delTCinsTAGC##LP             |->| Absent                        |->| ---
# VARIANT |->| c.0021_0039inv##PP                      |->| PRESENT  !!!!!!!!!!!!!!       |->| Diagnosis: PATHOLOGICAL
# VARIANT |->| c.0021_0039con0061_0079##LP             |->| Absent                        |->| ---
# VARIANT |->| c.0020G>T##BB                           |->| Absent                        |->| ---
# VARIANT |->| c.0015_0018del##LB                      |->| Absent                        |->| ---
# VARIANT |->| c.0019_0022delGGGA##PP                  |->| Absent                        |->| ---
# VARIANT |->| c.0019_0022dup##LP                      |->| Absent                        |->| ---
# VARIANT |->| c.0023_0026dupCAGG##NN                  |->| Absent                        |->| ---
# VARIANT |->| c.0022_0023insATATAT##BB                |->| Absent                        |->| ---
# VARIANT |->| c.0020_0021delinsCATG##LP               |->| Absent                        |->| ---
# VARIANT |->| c.0019_0020delGGinsCAGT##LP             |->| Absent                        |->| ---
# VARIANT |->| c.0031_0049inv##PP                      |->| Absent                        |->| ---
# VARIANT |->| c.0031_0049con0071_0089##LP             |->| Absent                        |->| ---
# VARIANT |->| c.0030T>A##BB                           |->| PRESENT  !!!!!!!!!!!!!!       |->| Diagnosis: BENIGN
# VARIANT |->| c.0025_0028del##LB                      |->| Absent                        |->| ---
# VARIANT |->| c.0030_0033delTGGG##PP                  |->| Absent                        |->| ---
# VARIANT |->| c.0029_0032dup##LP                      |->| Absent                        |->| ---
# VARIANT |->| c.0040_0043dupCAGA##NN                  |->| Absent                        |->| ---
# VARIANT |->| c.0032_0033insATATAT##BB                |->| Absent                        |->| ---
# VARIANT |->| c.0029_0030delinsGGAA##LP               |->| Absent                        |->| ---
# VARIANT |->| c.0029_0030delGTinsCCTT##LP             |->| Absent                        |->| ---
# VARIANT |->| c.0041_0059inv##PP                      |->| Absent                        |->| ---
# VARIANT |->| c.0041_0059con0081_0099##LP             |->| Absent                        |->| ---
# --------------------------------------------------------------------------------------------------------------------------
# For file:   P001-BRCA1-VAR10.fasta
# GCTGAGACTTCCTGGACGGG|GTCAGGAGGCCTTCACCCTC|CAGATAACTGGGCCCCTGCG|CTCAGGAGGCCTTCACCCTC|TGCTCTGGGTAAAGTTCATT
# GCTGAGACTTCCTGGACGGG|GGACAGGCTGTGGGGTTTCT|CAGATAACTGGGCCCCTGCG|CTCAGGAGGCCTTCACCCTC|TGCTCTGGGTAAAGTTCATT
# --------------------------------------------------------------------------------------------------------------------------
# VARIANT |->| c.0010C>T##BB                           |->| Absent                        |->| ---
# VARIANT |->| c.0005_0008del##LB                      |->| Absent                        |->| ---
# VARIANT |->| c.0009_0012delTCCT##PP                  |->| Absent                        |->| ---
# VARIANT |->| c.0009_0012dup##LP                      |->| Absent                        |->| ---
# VARIANT |->| c.0014_0017dupGACG##NN                  |->| Absent                        |->| ---
# VARIANT |->| c.0012_0013insATATAT##BB                |->| Absent                        |->| ---
# VARIANT |->| c.0009_0010delinsGGAA##LP               |->| Absent                        |->| ---
# VARIANT |->| c.0009_0010delTCinsTAGC##LP             |->| Absent                        |->| ---
# VARIANT |->| c.0021_0039inv##PP                      |->| Absent                        |->| ---
# VARIANT |->| c.0021_0039con0061_0079##LP             |->| PRESENT   !!!!!!!!!!!!!!      |->| Diagnosis: LIKELY PATHOLOGICAL
# VARIANT |->| c.0020G>T##BB                           |->| Absent                        |->| ---
# VARIANT |->| c.0015_0018del##LB                      |->| Absent                        |->| ---
# VARIANT |->| c.0019_0022delGGGA##PP                  |->| Absent                        |->| ---
# VARIANT |->| c.0019_0022dup##LP                      |->| Absent                        |->| ---
# VARIANT |->| c.0023_0026dupCAGG##NN                  |->| Absent                        |->| ---
# VARIANT |->| c.0022_0023insATATAT##BB                |->| Absent                        |->| ---
# VARIANT |->| c.0020_0021delinsCATG##LP               |->| Absent                        |->| ---
# VARIANT |->| c.0019_0020delGGinsCAGT##LP             |->| Absent                        |->| ---
# VARIANT |->| c.0031_0049inv##PP                      |->| Absent                        |->| ---
# VARIANT |->| c.0031_0049con0071_0089##LP             |->| Absent                        |->| ---
# VARIANT |->| c.0030T>A##BB                           |->| Absent                        |->| ---
# VARIANT |->| c.0025_0028del##LB                      |->| Absent                        |->| ---
# VARIANT |->| c.0030_0033delTGGG##PP                  |->| Absent                        |->| ---
# VARIANT |->| c.0029_0032dup##LP                      |->| Absent                        |->| ---
# VARIANT |->| c.0040_0043dupCAGA##NN                  |->| Absent                        |->| ---
# VARIANT |->| c.0032_0033insATATAT##BB                |->| Absent                        |->| ---
# VARIANT |->| c.0029_0030delinsGGAA##LP               |->| Absent                        |->| ---
# VARIANT |->| c.0029_0030delGTinsCCTT##LP             |->| Absent                        |->| ---
# VARIANT |->| c.0041_0059inv##PP                      |->| Absent                        |->| ---
# VARIANT |->| c.0041_0059con0081_0099##LP             |->| Absent                        |->| ---
# --------------------------------------------------------------------------------------------------------------------------
# For file:   P002-BRCA1-VAR01.fasta
# GCTGAGACTTCCTGGACGGG|TGACAGGCTGTGGGGTTTCT|CAGATAACTGGGCCCCTGCG|CTCAGGAGGCCTTCACCCTC|TGCTCTGGGTAAAGTTCATT
# GCTGAGACTTCCTGGACGGG|GGACAGGCTGTGGGGTTTCT|CAGATAACTGGGCCCCTGCG|CTCAGGAGGCCTTCACCCTC|TGCTCTGGGTAAAGTTCATT
# --------------------------------------------------------------------------------------------------------------------------
# VARIANT |->| c.0010C>T##BB                           |->| Absent                        |->| ---
# VARIANT |->| c.0005_0008del##LB                      |->| Absent                        |->| ---
# VARIANT |->| c.0009_0012delTCCT##PP                  |->| Absent                        |->| ---
# VARIANT |->| c.0009_0012dup##LP                      |->| Absent                        |->| ---
# VARIANT |->| c.0014_0017dupGACG##NN                  |->| Absent                        |->| ---
# VARIANT |->| c.0012_0013insATATAT##BB                |->| Absent                        |->| ---
# VARIANT |->| c.0009_0010delinsGGAA##LP               |->| Absent                        |->| ---
# VARIANT |->| c.0009_0010delTCinsTAGC##LP             |->| Absent                        |->| ---
# VARIANT |->| c.0021_0039inv##PP                      |->| Absent                        |->| ---
# VARIANT |->| c.0021_0039con0061_0079##LP             |->| Absent                        |->| ---
# VARIANT |->| c.0020G>T##BB                           |->| PRESENT  !!!!!!!!!!!!!!       |->| Diagnosis: BENIGN
# VARIANT |->| c.0015_0018del##LB                      |->| Absent                        |->| ---
# VARIANT |->| c.0019_0022delGGGA##PP                  |->| Absent                        |->| ---
# VARIANT |->| c.0019_0022dup##LP                      |->| Absent                        |->| ---
# VARIANT |->| c.0023_0026dupCAGG##NN                  |->| Absent                        |->| ---
# VARIANT |->| c.0022_0023insATATAT##BB                |->| Absent                        |->| ---
# VARIANT |->| c.0020_0021delinsCATG##LP               |->| Absent                        |->| ---
# VARIANT |->| c.0019_0020delGGinsCAGT##LP             |->| Absent                        |->| ---
# VARIANT |->| c.0031_0049inv##PP                      |->| Absent                        |->| ---
# VARIANT |->| c.0031_0049con0071_0089##LP             |->| Absent                        |->| ---
# VARIANT |->| c.0030T>A##BB                           |->| Absent                        |->| ---
# VARIANT |->| c.0025_0028del##LB                      |->| Absent                        |->| ---
# VARIANT |->| c.0030_0033delTGGG##PP                  |->| Absent                        |->| ---
# VARIANT |->| c.0029_0032dup##LP                      |->| Absent                        |->| ---
# VARIANT |->| c.0040_0043dupCAGA##NN                  |->| Absent                        |->| ---
# VARIANT |->| c.0032_0033insATATAT##BB                |->| Absent                        |->| ---
# VARIANT |->| c.0029_0030delinsGGAA##LP               |->| Absent                        |->| ---
# VARIANT |->| c.0029_0030delGTinsCCTT##LP             |->| Absent                        |->| ---
# VARIANT |->| c.0041_0059inv##PP                      |->| Absent                        |->| ---
# VARIANT |->| c.0041_0059con0081_0099##LP             |->| Absent                        |->| ---
# --------------------------------------------------------------------------------------------------------------------------
# For file:   P002-BRCA1-VAR02.fasta
# GCTGAGACTTCCTGGGGGAC|AGGCTGTGGGGTTTCTCAGA|TAACTGGGCCCCTGCGCTCA|GGAGGCCTTCACCCTCTGCT|CTGGGTAAAGTTCATTGGAA
# GCTGAGACTTCCTGGACGGG|GGACAGGCTGTGGGGTTTCT|CAGATAACTGGGCCCCTGCG|CTCAGGAGGCCTTCACCCTC|TGCTCTGGGTAAAGTTCATT
# --------------------------------------------------------------------------------------------------------------------------
# VARIANT |->| c.0010C>T##BB                           |->| Absent                        |->| ---
# VARIANT |->| c.0005_0008del##LB                      |->| Absent                        |->| ---
# VARIANT |->| c.0009_0012delTCCT##PP                  |->| Absent                        |->| ---
# VARIANT |->| c.0009_0012dup##LP                      |->| Absent                        |->| ---
# VARIANT |->| c.0014_0017dupGACG##NN                  |->| Absent                        |->| ---
# VARIANT |->| c.0012_0013insATATAT##BB                |->| Absent                        |->| ---
# VARIANT |->| c.0009_0010delinsGGAA##LP               |->| Absent                        |->| ---
# VARIANT |->| c.0009_0010delTCinsTAGC##LP             |->| Absent                        |->| ---
# VARIANT |->| c.0021_0039inv##PP                      |->| Absent                        |->| ---
# VARIANT |->| c.0021_0039con0061_0079##LP             |->| Absent                        |->| ---
# VARIANT |->| c.0020G>T##BB                           |->| Absent                        |->| ---
# VARIANT |->| c.0015_0018del##LB                      |->| PRESENT  !!!!!!!!!!!!!!       |->| Diagnosis: LIKELY BENIGN
# VARIANT |->| c.0019_0022delGGGA##PP                  |->| Absent                        |->| ---
# VARIANT |->| c.0019_0022dup##LP                      |->| Absent                        |->| ---
# VARIANT |->| c.0023_0026dupCAGG##NN                  |->| Absent                        |->| ---
# VARIANT |->| c.0022_0023insATATAT##BB                |->| Absent                        |->| ---
# VARIANT |->| c.0020_0021delinsCATG##LP               |->| Absent                        |->| ---
# VARIANT |->| c.0019_0020delGGinsCAGT##LP             |->| Absent                        |->| ---
# VARIANT |->| c.0031_0049inv##PP                      |->| Absent                        |->| ---
# VARIANT |->| c.0031_0049con0071_0089##LP             |->| Absent                        |->| ---
# VARIANT |->| c.0030T>A##BB                           |->| Absent                        |->| ---
# VARIANT |->| c.0025_0028del##LB                      |->| Absent                        |->| ---
# VARIANT |->| c.0030_0033delTGGG##PP                  |->| Absent                        |->| ---
# VARIANT |->| c.0029_0032dup##LP                      |->| Absent                        |->| ---
# VARIANT |->| c.0040_0043dupCAGA##NN                  |->| Absent                        |->| ---
# VARIANT |->| c.0032_0033insATATAT##BB                |->| Absent                        |->| ---
# VARIANT |->| c.0029_0030delinsGGAA##LP               |->| Absent                        |->| ---
# VARIANT |->| c.0029_0030delGTinsCCTT##LP             |->| Absent                        |->| ---
# VARIANT |->| c.0041_0059inv##PP                      |->| Absent                        |->| ---
# VARIANT |->| c.0041_0059con0081_0099##LP             |->| Absent                        |->| ---
# --------------------------------------------------------------------------------------------------------------------------
# For file:   P002-BRCA1-VAR03.fasta
# GCTGAGACTTCCTGGACGGC|AGGCTGTGGGGTTTCTCAGA|TAACTGGGCCCCTGCGCTCA|GGAGGCCTTCACCCTCTGCT|CTGGGTAAAGTTCATTGGAA
# GCTGAGACTTCCTGGACGGG|GGACAGGCTGTGGGGTTTCT|CAGATAACTGGGCCCCTGCG|CTCAGGAGGCCTTCACCCTC|TGCTCTGGGTAAAGTTCATT
# --------------------------------------------------------------------------------------------------------------------------
# VARIANT |->| c.0010C>T##BB                           |->| Absent                        |->| ---
# VARIANT |->| c.0005_0008del##LB                      |->| Absent                        |->| ---
# VARIANT |->| c.0009_0012delTCCT##PP                  |->| Absent                        |->| ---
# VARIANT |->| c.0009_0012dup##LP                      |->| Absent                        |->| ---
# VARIANT |->| c.0014_0017dupGACG##NN                  |->| Absent                        |->| ---
# VARIANT |->| c.0012_0013insATATAT##BB                |->| Absent                        |->| ---
# VARIANT |->| c.0009_0010delinsGGAA##LP               |->| Absent                        |->| ---
# VARIANT |->| c.0009_0010delTCinsTAGC##LP             |->| Absent                        |->| ---
# VARIANT |->| c.0021_0039inv##PP                      |->| Absent                        |->| ---
# VARIANT |->| c.0021_0039con0061_0079##LP             |->| Absent                        |->| ---
# VARIANT |->| c.0020G>T##BB                           |->| Absent                        |->| ---
# VARIANT |->| c.0015_0018del##LB                      |->| Absent                        |->| ---
# VARIANT |->| c.0019_0022delGGGA##PP                  |->| PRESENT  !!!!!!!!!!!!!!       |->| Diagnosis: PATHOLOGICAL
# VARIANT |->| c.0019_0022dup##LP                      |->| Absent                        |->| ---
# VARIANT |->| c.0023_0026dupCAGG##NN                  |->| Absent                        |->| ---
# VARIANT |->| c.0022_0023insATATAT##BB                |->| Absent                        |->| ---
# VARIANT |->| c.0020_0021delinsCATG##LP               |->| Absent                        |->| ---
# VARIANT |->| c.0019_0020delGGinsCAGT##LP             |->| Absent                        |->| ---
# VARIANT |->| c.0031_0049inv##PP                      |->| Absent                        |->| ---
# VARIANT |->| c.0031_0049con0071_0089##LP             |->| Absent                        |->| ---
# VARIANT |->| c.0030T>A##BB                           |->| Absent                        |->| ---
# VARIANT |->| c.0025_0028del##LB                      |->| Absent                        |->| ---
# VARIANT |->| c.0030_0033delTGGG##PP                  |->| Absent                        |->| ---
# VARIANT |->| c.0029_0032dup##LP                      |->| Absent                        |->| ---
# VARIANT |->| c.0040_0043dupCAGA##NN                  |->| Absent                        |->| ---
# VARIANT |->| c.0032_0033insATATAT##BB                |->| Absent                        |->| ---
# VARIANT |->| c.0029_0030delinsGGAA##LP               |->| Absent                        |->| ---
# VARIANT |->| c.0029_0030delGTinsCCTT##LP             |->| Absent                        |->| ---
# VARIANT |->| c.0041_0059inv##PP                      |->| Absent                        |->| ---
# VARIANT |->| c.0041_0059con0081_0099##LP             |->| Absent                        |->| ---
# --------------------------------------------------------------------------------------------------------------------------
# For file:   P002-BRCA1-VAR04.fasta
# GCTGAGACTTCCTGGACGGT|CCTGGGACAGGCTGTGGGGT|TTCTCAGATAACTGGGCCCC|TGCGCTCAGGAGGCCTTCAC|CCTCTGCTCTGGGTAAAGTT
# GCTGAGACTTCCTGGACGGG|GGACAGGCTGTGGGGTTTCT|CAGATAACTGGGCCCCTGCG|CTCAGGAGGCCTTCACCCTC|TGCTCTGGGTAAAGTTCATT
# --------------------------------------------------------------------------------------------------------------------------
# VARIANT |->| c.0010C>T##BB                           |->| Absent                        |->| ---
# VARIANT |->| c.0005_0008del##LB                      |->| Absent                        |->| ---
# VARIANT |->| c.0009_0012delTCCT##PP                  |->| Absent                        |->| ---
# VARIANT |->| c.0009_0012dup##LP                      |->| Absent                        |->| ---
# VARIANT |->| c.0014_0017dupGACG##NN                  |->| Absent                        |->| ---
# VARIANT |->| c.0012_0013insATATAT##BB                |->| Absent                        |->| ---
# VARIANT |->| c.0009_0010delinsGGAA##LP               |->| Absent                        |->| ---
# VARIANT |->| c.0009_0010delTCinsTAGC##LP             |->| Absent                        |->| ---
# VARIANT |->| c.0021_0039inv##PP                      |->| Absent                        |->| ---
# VARIANT |->| c.0021_0039con0061_0079##LP             |->| Absent                        |->| ---
# VARIANT |->| c.0020G>T##BB                           |->| Absent                        |->| ---
# VARIANT |->| c.0015_0018del##LB                      |->| Absent                        |->| ---
# VARIANT |->| c.0019_0022delGGGA##PP                  |->| Absent                        |->| ---
# VARIANT |->| c.0019_0022dup##LP                      |->| PRESENT  !!!!!!!!!!!!!!       |->| Diagnosis: LIKELY PATHOLOGICAL
# VARIANT |->| c.0023_0026dupCAGG##NN                  |->| Absent                        |->| ---
# VARIANT |->| c.0022_0023insATATAT##BB                |->| Absent                        |->| ---
# VARIANT |->| c.0020_0021delinsCATG##LP               |->| Absent                        |->| ---
# VARIANT |->| c.0019_0020delGGinsCAGT##LP             |->| Absent                        |->| ---
# VARIANT |->| c.0031_0049inv##PP                      |->| Absent                        |->| ---
# VARIANT |->| c.0031_0049con0071_0089##LP             |->| Absent                        |->| ---
# VARIANT |->| c.0030T>A##BB                           |->| Absent                        |->| ---
# VARIANT |->| c.0025_0028del##LB                      |->| Absent                        |->| ---
# VARIANT |->| c.0030_0033delTGGG##PP                  |->| Absent                        |->| ---
# VARIANT |->| c.0029_0032dup##LP                      |->| Absent                        |->| ---
# VARIANT |->| c.0040_0043dupCAGA##NN                  |->| Absent                        |->| ---
# VARIANT |->| c.0032_0033insATATAT##BB                |->| Absent                        |->| ---
# VARIANT |->| c.0029_0030delinsGGAA##LP               |->| Absent                        |->| ---
# ...
# VARIANT |->| c.0020G>T##BB                           |->| Absent                        |->| ---
# VARIANT |->| c.0015_0018del##LB                      |->| Absent                        |->| ---
# VARIANT |->| c.0019_0022delGGGA##PP                  |->| Absent                        |->| ---
# VARIANT |->| c.0019_0022dup##LP                      |->| Absent                        |->| ---
# VARIANT |->| c.0023_0026dupCAGG##NN                  |->| Absent                        |->| ---
# VARIANT |->| c.0022_0023insATATAT##BB                |->| Absent                        |->| ---
# VARIANT |->| c.0020_0021delinsCATG##LP               |->| Absent                        |->| ---
# VARIANT |->| c.0019_0020delGGinsCAGT##LP             |->| Absent                        |->| ---
# VARIANT |->| c.0031_0049inv##PP                      |->| Absent                        |->| ---
# VARIANT |->| c.0031_0049con0071_0089##LP             |->| Absent                        |->| ---
# VARIANT |->| c.0030T>A##BB                           |->| Absent                        |->| ---
# VARIANT |->| c.0025_0028del##LB                      |->| Absent                        |->| ---
# VARIANT |->| c.0030_0033delTGGG##PP                  |->| Absent                        |->| ---
# VARIANT |->| c.0029_0032dup##LP                      |->| Absent                        |->| ---
# VARIANT |->| c.0040_0043dupCAGA##NN                  |->| Absent                        |->| ---
# VARIANT |->| c.0032_0033insATATAT##BB                |->| PRESENT  !!!!!!!!!!!!!!       |->| Diagnosis: BENIGN
# VARIANT |->| c.0029_0030delinsGGAA##LP               |->| Absent                        |->| ---
# VARIANT |->| c.0029_0030delGTinsCCTT##LP             |->| Absent                        |->| ---
# VARIANT |->| c.0041_0059inv##PP                      |->| Absent                        |->| ---
# VARIANT |->| c.0041_0059con0081_0099##LP             |->| Absent                        |->| ---
# --------------------------------------------------------------------------------------------------------------------------
# For file:   P003-BRCA1-VAR07.fasta
# GCTGAGACTTCCTGGACGGG|GGACAGGCTGGAAGGGGTTT|CTCAGATAACTGGGCCCCTG|CGCTCAGGAGGCCTTCACCC|TCTGCTCTGGGTAAAGTTCA
# GCTGAGACTTCCTGGACGGG|GGACAGGCTGTGGGGTTTCT|CAGATAACTGGGCCCCTGCG|CTCAGGAGGCCTTCACCCTC|TGCTCTGGGTAAAGTTCATT
# --------------------------------------------------------------------------------------------------------------------------
# VARIANT |->| c.0010C>T##BB                           |->| Absent                        |->| ---
# VARIANT |->| c.0005_0008del##LB                      |->| Absent                        |->| ---
# VARIANT |->| c.0009_0012delTCCT##PP                  |->| Absent                        |->| ---
# VARIANT |->| c.0009_0012dup##LP                      |->| Absent                        |->| ---
# VARIANT |->| c.0014_0017dupGACG##NN                  |->| Absent                        |->| ---
# VARIANT |->| c.0012_0013insATATAT##BB                |->| Absent                        |->| ---
# VARIANT |->| c.0009_0010delinsGGAA##LP               |->| Absent                        |->| ---
# VARIANT |->| c.0009_0010delTCinsTAGC##LP             |->| Absent                        |->| ---
# VARIANT |->| c.0021_0039inv##PP                      |->| Absent                        |->| ---
# VARIANT |->| c.0021_0039con0061_0079##LP             |->| Absent                        |->| ---
# VARIANT |->| c.0020G>T##BB                           |->| Absent                        |->| ---
# VARIANT |->| c.0015_0018del##LB                      |->| Absent                        |->| ---
# VARIANT |->| c.0019_0022delGGGA##PP                  |->| Absent                        |->| ---
# VARIANT |->| c.0019_0022dup##LP                      |->| Absent                        |->| ---
# VARIANT |->| c.0023_0026dupCAGG##NN                  |->| Absent                        |->| ---
# VARIANT |->| c.0022_0023insATATAT##BB                |->| Absent                        |->| ---
# VARIANT |->| c.0020_0021delinsCATG##LP               |->| Absent                        |->| ---
# VARIANT |->| c.0019_0020delGGinsCAGT##LP             |->| Absent                        |->| ---
# VARIANT |->| c.0031_0049inv##PP                      |->| Absent                        |->| ---
# VARIANT |->| c.0031_0049con0071_0089##LP             |->| Absent                        |->| ---
# VARIANT |->| c.0030T>A##BB                           |->| Absent                        |->| ---
# VARIANT |->| c.0025_0028del##LB                      |->| Absent                        |->| ---
# VARIANT |->| c.0030_0033delTGGG##PP                  |->| Absent                        |->| ---
# VARIANT |->| c.0029_0032dup##LP                      |->| Absent                        |->| ---
# VARIANT |->| c.0040_0043dupCAGA##NN                  |->| Absent                        |->| ---
# VARIANT |->| c.0032_0033insATATAT##BB                |->| Absent                        |->| ---
# VARIANT |->| c.0029_0030delinsGGAA##LP               |->| PRESENT  !!!!!!!!!!!!!!       |->| Diagnosis: LIKELY PATHOLOGICAL
# VARIANT |->| c.0029_0030delGTinsCCTT##LP             |->| Absent                        |->| ---
# VARIANT |->| c.0041_0059inv##PP                      |->| Absent                        |->| ---
# VARIANT |->| c.0041_0059con0081_0099##LP             |->| Absent                        |->| ---
# --------------------------------------------------------------------------------------------------------------------------
# For file:   P003-BRCA1-VAR08.fasta
# GCTGAGACTTCCTGGACGGG|GGACAGGCTCCTTGGGGTTT|CTCAGATAACTGGGCCCCTG|CGCTCAGGAGGCCTTCACCC|TCTGCTCTGGGTAAAGTTCA
# GCTGAGACTTCCTGGACGGG|GGACAGGCTGTGGGGTTTCT|CAGATAACTGGGCCCCTGCG|CTCAGGAGGCCTTCACCCTC|TGCTCTGGGTAAAGTTCATT
# --------------------------------------------------------------------------------------------------------------------------
# VARIANT |->| c.0010C>T##BB                           |->| Absent                        |->| ---
# VARIANT |->| c.0005_0008del##LB                      |->| Absent                        |->| ---
# VARIANT |->| c.0009_0012delTCCT##PP                  |->| Absent                        |->| ---
# VARIANT |->| c.0009_0012dup##LP                      |->| Absent                        |->| ---
# VARIANT |->| c.0014_0017dupGACG##NN                  |->| Absent                        |->| ---
# VARIANT |->| c.0012_0013insATATAT##BB                |->| Absent                        |->| ---
# VARIANT |->| c.0009_0010delinsGGAA##LP               |->| Absent                        |->| ---
# VARIANT |->| c.0009_0010delTCinsTAGC##LP             |->| Absent                        |->| ---
# VARIANT |->| c.0021_0039inv##PP                      |->| Absent                        |->| ---
# VARIANT |->| c.0021_0039con0061_0079##LP             |->| Absent                        |->| ---
# VARIANT |->| c.0020G>T##BB                           |->| Absent                        |->| ---
# VARIANT |->| c.0015_0018del##LB                      |->| Absent                        |->| ---
# VARIANT |->| c.0019_0022delGGGA##PP                  |->| Absent                        |->| ---
# VARIANT |->| c.0019_0022dup##LP                      |->| Absent                        |->| ---
# VARIANT |->| c.0023_0026dupCAGG##NN                  |->| Absent                        |->| ---
# VARIANT |->| c.0022_0023insATATAT##BB                |->| Absent                        |->| ---
# VARIANT |->| c.0020_0021delinsCATG##LP               |->| Absent                        |->| ---
# VARIANT |->| c.0019_0020delGGinsCAGT##LP             |->| Absent                        |->| ---
# VARIANT |->| c.0031_0049inv##PP                      |->| Absent                        |->| ---
# VARIANT |->| c.0031_0049con0071_0089##LP             |->| Absent                        |->| ---
# VARIANT |->| c.0030T>A##BB                           |->| Absent                        |->| ---
# VARIANT |->| c.0025_0028del##LB                      |->| Absent                        |->| ---
# VARIANT |->| c.0030_0033delTGGG##PP                  |->| Absent                        |->| ---
# VARIANT |->| c.0029_0032dup##LP                      |->| Absent                        |->| ---
# VARIANT |->| c.0040_0043dupCAGA##NN                  |->| Absent                        |->| ---
# VARIANT |->| c.0032_0033insATATAT##BB                |->| Absent                        |->| ---
# VARIANT |->| c.0029_0030delinsGGAA##LP               |->| Absent                        |->| ---
# VARIANT |->| c.0029_0030delGTinsCCTT##LP             |->| PRESENT  !!!!!!!!!!!!!!       |->| Diagnosis: LIKELY PATHOLOGICAL
# VARIANT |->| c.0041_0059inv##PP                      |->| Absent                        |->| ---
# VARIANT |->| c.0041_0059con0081_0099##LP             |->| Absent                        |->| ---
# --------------------------------------------------------------------------------------------------------------------------
# For file:   P003-BRCA1-VAR09.fasta
# GCTGAGACTTCCTGGACGGG|GGACAGGCTGTGGGGTTTCT|CCGCAGGGGCCCAGTTATCT|CTCAGGAGGCCTTCACCCTC|TGCTCTGGGTAAAGTTCATT
# GCTGAGACTTCCTGGACGGG|GGACAGGCTGTGGGGTTTCT|CAGATAACTGGGCCCCTGCG|CTCAGGAGGCCTTCACCCTC|TGCTCTGGGTAAAGTTCATT
# --------------------------------------------------------------------------------------------------------------------------
# VARIANT |->| c.0010C>T##BB                           |->| Absent                        |->| ---
# VARIANT |->| c.0005_0008del##LB                      |->| Absent                        |->| ---
# VARIANT |->| c.0009_0012delTCCT##PP                  |->| Absent                        |->| ---
# VARIANT |->| c.0009_0012dup##LP                      |->| Absent                        |->| ---
# VARIANT |->| c.0014_0017dupGACG##NN                  |->| Absent                        |->| ---
# VARIANT |->| c.0012_0013insATATAT##BB                |->| Absent                        |->| ---
# VARIANT |->| c.0009_0010delinsGGAA##LP               |->| Absent                        |->| ---
# VARIANT |->| c.0009_0010delTCinsTAGC##LP             |->| Absent                        |->| ---
# VARIANT |->| c.0021_0039inv##PP                      |->| Absent                        |->| ---
# VARIANT |->| c.0021_0039con0061_0079##LP             |->| Absent                        |->| ---
# VARIANT |->| c.0020G>T##BB                           |->| Absent                        |->| ---
# VARIANT |->| c.0015_0018del##LB                      |->| Absent                        |->| ---
# VARIANT |->| c.0019_0022delGGGA##PP                  |->| Absent                        |->| ---
# VARIANT |->| c.0019_0022dup##LP                      |->| Absent                        |->| ---
# VARIANT |->| c.0023_0026dupCAGG##NN                  |->| Absent                        |->| ---
# VARIANT |->| c.0022_0023insATATAT##BB                |->| Absent                        |->| ---
# VARIANT |->| c.0020_0021delinsCATG##LP               |->| Absent                        |->| ---
# VARIANT |->| c.0019_0020delGGinsCAGT##LP             |->| Absent                        |->| ---
# VARIANT |->| c.0031_0049inv##PP                      |->| Absent                        |->| ---
# VARIANT |->| c.0031_0049con0071_0089##LP             |->| Absent                        |->| ---
# VARIANT |->| c.0030T>A##BB                           |->| Absent                        |->| ---
# VARIANT |->| c.0025_0028del##LB                      |->| Absent                        |->| ---
# VARIANT |->| c.0030_0033delTGGG##PP                  |->| Absent                        |->| ---
# VARIANT |->| c.0029_0032dup##LP                      |->| Absent                        |->| ---
# VARIANT |->| c.0040_0043dupCAGA##NN                  |->| Absent                        |->| ---
# VARIANT |->| c.0032_0033insATATAT##BB                |->| Absent                        |->| ---
# VARIANT |->| c.0029_0030delinsGGAA##LP               |->| Absent                        |->| ---
# VARIANT |->| c.0029_0030delGTinsCCTT##LP             |->| Absent                        |->| ---
# VARIANT |->| c.0041_0059inv##PP                      |->| PRESENT  !!!!!!!!!!!!!!       |->| Diagnosis: PATHOLOGICAL
# VARIANT |->| c.0041_0059con0081_0099##LP             |->| Absent                        |->| ---
# --------------------------------------------------------------------------------------------------------------------------
# For file:   P003-BRCA1-VAR10.fasta
# GCTGAGACTTCCTGGACGGG|GGACAGGCTGTGGGGTTTCT|CGCTCTGGGTAAAGTTCATT|CTCAGGAGGCCTTCACCCTC|TGCTCTGGGTAAAGTTCATT
# GCTGAGACTTCCTGGACGGG|GGACAGGCTGTGGGGTTTCT|CAGATAACTGGGCCCCTGCG|CTCAGGAGGCCTTCACCCTC|TGCTCTGGGTAAAGTTCATT
# --------------------------------------------------------------------------------------------------------------------------
# VARIANT |->| c.0010C>T##BB                           |->| Absent                        |->| ---
# VARIANT |->| c.0005_0008del##LB                      |->| Absent                        |->| ---
# VARIANT |->| c.0009_0012delTCCT##PP                  |->| Absent                        |->| ---
# VARIANT |->| c.0009_0012dup##LP                      |->| Absent                        |->| ---
# VARIANT |->| c.0014_0017dupGACG##NN                  |->| Absent                        |->| ---
# VARIANT |->| c.0012_0013insATATAT##BB                |->| Absent                        |->| ---
# VARIANT |->| c.0009_0010delinsGGAA##LP               |->| Absent                        |->| ---
# VARIANT |->| c.0009_0010delTCinsTAGC##LP             |->| Absent                        |->| ---
# VARIANT |->| c.0021_0039inv##PP                      |->| Absent                        |->| ---
# VARIANT |->| c.0021_0039con0061_0079##LP             |->| Absent                        |->| ---
# VARIANT |->| c.0020G>T##BB                           |->| Absent                        |->| ---
# VARIANT |->| c.0015_0018del##LB                      |->| Absent                        |->| ---
# VARIANT |->| c.0019_0022delGGGA##PP                  |->| Absent                        |->| ---
# VARIANT |->| c.0019_0022dup##LP                      |->| Absent                        |->| ---
# VARIANT |->| c.0023_0026dupCAGG##NN                  |->| Absent                        |->| ---
# VARIANT |->| c.0022_0023insATATAT##BB                |->| Absent                        |->| ---
# VARIANT |->| c.0020_0021delinsCATG##LP               |->| Absent                        |->| ---
# VARIANT |->| c.0019_0020delGGinsCAGT##LP             |->| Absent                        |->| ---
# VARIANT |->| c.0031_0049inv##PP                      |->| Absent                        |->| ---
# VARIANT |->| c.0031_0049con0071_0089##LP             |->| Absent                        |->| ---
# VARIANT |->| c.0030T>A##BB                           |->| Absent                        |->| ---
# VARIANT |->| c.0025_0028del##LB                      |->| Absent                        |->| ---
# VARIANT |->| c.0030_0033delTGGG##PP                  |->| Absent                        |->| ---
# VARIANT |->| c.0029_0032dup##LP                      |->| Absent                        |->| ---
# VARIANT |->| c.0040_0043dupCAGA##NN                  |->| Absent                        |->| ---
# VARIANT |->| c.0032_0033insATATAT##BB                |->| Absent                        |->| ---
# VARIANT |->| c.0029_0030delinsGGAA##LP               |->| Absent                        |->| ---
# VARIANT |->| c.0029_0030delGTinsCCTT##LP             |->| Absent                        |->| ---
# VARIANT |->| c.0041_0059inv##PP                      |->| Absent                        |->| ---
# VARIANT |->| c.0041_0059con0081_0099##LP             |->| PRESENT   !!!!!!!!!!!!!!      |->| Diagnosis: LIKELY PATHOLOGICAL
# --------------------------------------------------------------------------------------------------------------------------
# ===============================================END OF GENOMICS REPORT=====================================================

# %%
import datetime
currenttime = datetime.datetime.now()

newfilename='genomicsreportfile'+'-'+str(currenttime.year)+'-'+str(currenttime.month)+'-'+str(currenttime.day)+'-'+str(currenttime.hour)\
    +'-'+str(currenttime.minute)+'-'+str(currenttime.second)+'-'+str(currenttime.microsecond)+'.txt'
fileobject = open(newfilename, 'w')
for i in range(len(reportlines)):
    fileobject.write(str(reportlines[i]))
    fileobject.write('\n')
fileobject.close()

# %%
from fpdf import FPDF 
import datetime 
pdf = FPDF()     
pdf.add_page() 
pdf.set_font("Arial", size = 8) 
currenttime = datetime.datetime.now()
strpdffilename='genomicsreportfile'+'-'+str(currenttime.year)+'-'+str(currenttime.month)+'-'+str(currenttime.day)+'-'+str(currenttime.hour)\
    +'-'+str(currenttime.minute)+'-'+str(currenttime.second)+'-'+str(currenttime.microsecond)+'.pdf'

for i in range(len(reportlines)):
    #fileobject.write(str(reportlines[i]))
    pdf.cell(200, 10, txt = str(reportlines[i]), ln = i+1, align = 'L')
    
# save the pdf with name .pdf 
pdf.output(strpdffilename)
# Out:
# ''
